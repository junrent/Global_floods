# %%
import os, time
import country_converter as coco

from osgeo import gdal
import pandas as pd 
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path 
import pycountry 

import rasterio as rs
from rasterio.plot import show
from rasterio.enums import Resampling
from rasterio.plot import plotting_extent
from rasterio.merge import merge
import rasterio.mask
from rasterio import shutil as rio_shutil
from rasterio.vrt import WarpedVRT

def tPrint(s):
    print("%s\t%s" % (time.strftime("%H:%M:%S"), s))

# %%
path = Path('/Users/bjafino/Documents/GitHub/PovertyClimateFall2020/FATHOM')

# World Admin
worldAdmin_Folder = 'GMGD_world_admin'
admin_File = 'newold_geo_code2_povdata_v7.shp'

reproj_Folder = 'GMGD_reproj'
admin_File_proj = 'WB_CountryPolys.shp'

# Pluvial and fluvial flood files (Fathom) - 2019
flood_Folder = 'FLOOD_SSBN'
flood_subFolder_2019 = 'v2_2019'
fluvialFlood_Folder = 'fluvial_undefended'
fluvialFlood_FileName = 'FU_1in100.tif' 
pluvialFlood_Folder = 'pluvial'
pluvialFlood_FileName = 'P_1in100.tif' 

# Pluvial and fluvial flood files (Fathom) - 2016
flood_subFolder_2016 = 'v1_2016'
## The pluvial and fluvial folder names are prepended with each country's ISO2 code
## This is managed in the 2016 analysis loop

# Coastal flood files
coastalFlood_Folder = 'Coastal_flood'
coastalFlood_File = "ss_muis_rp0100m.tif"

# Population data
pop_Folder = 'Population'
pop_subFolder = 'WorldPop_PPP_2020'
pop_subsubFolder = 'MOSAIC_ppp_prj_2020'

# Folder paths
flood_path_2019 = path / flood_Folder / flood_subFolder_2019 
flood_path_2016 = path / flood_Folder / flood_subFolder_2016 
population_path = path / pop_Folder / pop_subFolder / pop_subsubFolder 

# Global files paths
adm_path_reproj = path / worldAdmin_Folder / reproj_Folder / admin_File_proj
adm_path = path / worldAdmin_Folder / admin_File
coastalFlood_path = path / coastalFlood_Folder / coastalFlood_File
 
print(flood_path_2019)
print(flood_path_2016)
print(population_path)
print(adm_path)
print(coastalFlood_path)
# Out:
# \Users\bjafino\Documents\GitHub\PovertyClimateFall2020\FATHOM\FLOOD_SSBN\v2_2019
# \Users\bjafino\Documents\GitHub\PovertyClimateFall2020\FATHOM\FLOOD_SSBN\v1_2016
# \Users\bjafino\Documents\GitHub\PovertyClimateFall2020\FATHOM\Population\WorldPop_PPP_2020\MOSAIC_ppp_prj_2020
# \Users\bjafino\Documents\GitHub\PovertyClimateFall2020\FATHOM\GMGD_world_admin\newold_geo_code2_povdata_v7.shp
# \Users\bjafino\Documents\GitHub\PovertyClimateFall2020\FATHOM\Coastal_flood\ss_muis_rp0100m.tif

# %%
outputPath = Path('/Users/bjafino/Documents/GitHub/PovertyClimateFall2020/FATHOM')

# %% [markdown]
# <a id='Previous'></a>
# ## Previously Processed Countries
# If there are any previously processed countries, uncomment the second cell below.
# Otherwise, make sure the cell is commented out.
#
# After commenting/uncommenting the previously processed:
# - Run all cells until [here](#TOC), where you can then select the appropriate section

# %%
previouslyProcessed = []

# %%
# Comment out below if previously processed results do not exist or if you wish to rewrite

try:
    processed = gpd.read_file(outputPath /"Outputs"/"Results"/ "processed_countries.shp")
    previouslyProcessed = processed['ISO3'].unique()
    del processed
except:
    pass

# %%
previouslyProcessed
# Out:
# []

# %% [markdown]
# ## Creating folders for intermediate & final outputs

# %%
# Creating folder for all outputs
output_Folder = 'Outputs'
output_FolderPath = outputPath / output_Folder
try: 
    output_FolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for raster outputs
Raster_outputFolder = 'FloodPop_Countries'
Raster_outputFolderPath = output_FolderPath / Raster_outputFolder
try: 
    Raster_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for coastal flood country files
cFlood_outputFolder = 'CoastalFlood_Countries'
cFlood_outputFolderPath = output_FolderPath / cFlood_outputFolder
try: 
    cFlood_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for aggregated flood country files (fluvial + pluvial + coastal)
Flood_outputFolder = 'Flood_Countries'
Flood_outputFolderPath = output_FolderPath / Flood_outputFolder
try: 
    Flood_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for fluvial and pluvial merged flood files
PopAligned_outputFolder = 'Pop_aligned'
PopAligned_outputFolderPath = output_FolderPath / PopAligned_outputFolder
try: 
    PopAligned_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for fluvial and pluvial merged flood files
FP_outputFolder = 'FluvialPluvial'
FP_outputFolderPath = output_FolderPath / FP_outputFolder
try: 
    FP_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %%
# Creating folder for final results
Results_outputFolder = 'Results'
Results_outputFolderPath = output_FolderPath / Results_outputFolder
try: 
    Results_outputFolderPath.mkdir()
except FileExistsError:
    print('Already exists')
# Out:
# Already exists

# %% [markdown]
# ## Flood Bins
# 0. No risk: x = 0
# 1. Limited risk: x <= 0.15
# 2. Moderate risk: 0.15 < x <= 0.5
# 3. High risk: 0.5 < x <= 1.5
# 4. Very high risk: x > 1.5
# 5. Water body: x >= 999

# %%
flood_bins = [1e-10,0.15,0.5,1.5,998,10000] 
# Right=True when digitizing to include right bin edge
# Note: 0 contains flood depths of 0 up to 0.0000000001 -> no flood
numberCategories = len(flood_bins)

# %% [markdown]
# ## Result Dataframe

# %%
# An empty dataframe to store the results of each loop
result = pd.DataFrame(columns = ['OBJECTID',
                                '0-NoRiskPop',
                                '1-LowRiskPop', 
                                '2-ModerateRiskPop', 
                                '3-HighRiskPop', 
                                '4-VeryHighRiskPop', 
                                '5-WaterBodyPop',
                                'ISO3']).set_index('OBJECTID')

# %% [markdown]
# ## Admin shapefiles

# %%
# Read shapefile
adm = gpd.read_file(adm_path)
# adm = gpd.read_file(adm_path_reproj)
adm = adm[['code','sample','region','geo_code2','geometry']]

# %%
adm.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# Reproject to EPSG:4326
# adm = adm.to_crs('EPSG:4326')

# %%
# Correcting country codes
adm['ISO3'] = adm['code']
adm.ISO3 = adm.ISO3.replace('ADO', 'AND')
adm.ISO3 = adm.ISO3.replace('IMY', 'IMN')
adm.ISO3 = adm.ISO3.replace('URU', 'URY')
adm.ISO3 = adm.ISO3.replace('VNZ', 'VEN')
adm.ISO3 = adm.ISO3.replace('MOR', 'MAR')
#Kosovo WorldPop was originally KOS, then manually changed to XKX on the server

# %% [markdown]
# ## Matching adm country names to folder/file names

# %%
# Get country codes from adm df
codeDF = adm[['ISO3']]
codeDF = codeDF.drop_duplicates(subset ="ISO3")
codeDF = codeDF.sort_values(by=['ISO3'])

# Put adm country names in list for easier comparison
admCodeList = codeDF.ISO3.values.tolist()
admList = coco.convert(names=admCodeList, to='name_short')
#admList.sort()

# Add country names to df
codeDF['ADM0_NAME'] = admList
adm = adm.merge(codeDF, on='ISO3', how='left')
# Out:
# C:\Users\bjafino\anaconda3\envs\GMTRA\lib\site-packages\country_converter\country_converter.py:412: FutureWarning: read_table is deprecated, use read_csv instead.
#   for str_col in must_be_string})

# %%
# Get folder names for the Fathom data
list2019 = [os.path.basename(str(x)) for x in flood_path_2019.iterdir() if x.is_dir()]
# list2016 = [os.path.basename(str(x)) for x in flood_path_2016.iterdir() if x.is_dir()]

# %%
len(list2019)
# Out:
# 226

# %%
# Match country names from lists - 2019
matching_dict_2019 = coco.match(admList, list2019);
# Out:
# WARNING:root:Could not find any correspondence for Cabo Verde in list_b
# WARNING:root:Could not find any correspondence for Curacao in list_b
# WARNING:root:Multiple matches for name Fiji in list_b
# WARNING:root:Could not find any correspondence for Greenland in list_b
# WARNING:root:Could not find any correspondence for Isle of Man in list_b
# WARNING:root:Could not find any correspondence for Liechtenstein in list_b
# WARNING:root:Could not find any correspondence for Macao in list_b
# WARNING:root:Could not find any correspondence for Saint-Martin in list_b
# WARNING:root:Could not find any correspondence for Northern Mariana Islands in list_b
# WARNING:root:Could not find any correspondence for Palestine in list_b
# WARNING:root:Could not find any correspondence for Qatar in list_b
# WARNING:root:Could not find any correspondence for Russia in list_b
# WARNING:root:Could not find any correspondence for Sudan in list_b
# WARNING:root:Could not find any correspondence for Svalbard and Jan Mayen Islands in list_b
# WARNING:root:Multiple matches for name Sierra Leone in list_b
# WARNING:root:Could not find any correspondence for Sao Tome and Principe in list_b
# WARNING:root:Could not find any correspondence for Sint Maarten in list_b
# WARNING:root:Could not find any correspondence for Taiwan in list_b
# WARNING:root:Could not find any correspondence for United States in list_b

# %% [markdown]
# ## Correcting specific cases

# %%
# Sierra Leone has two folders, selecting one
if type(matching_dict_2019['Sierra Leone']) is list:
    matching_dict_2019['Sierra Leone'] = 'Sierra Leone'

# %%
# Fiji flood files are separated into Fiji_west and Fiji_east
for name in flood_path_2019.glob('Fiji_west'):
    fluvialFolder = flood_path_2019 / name / fluvialFlood_Folder
    FJfluvial = list(fluvialFolder.rglob('*100.tif'))
    
for name in flood_path_2019.glob('Fiji_east'):
    pluvialFolder = flood_path_2019 / name / pluvialFlood_Folder
    FJ_E_pluvial = list(pluvialFolder.rglob('*100.tif'))
    
for name in flood_path_2019.glob('Fiji_west'):
    pluvialFolder = flood_path_2019 / name / pluvialFlood_Folder
    FJ_W_pluvial = list(pluvialFolder.rglob('*100.tif'))

# %%
# Reorder so geometry is the last col
adm = adm[['ADM0_NAME','code','ISO3','sample','region','geo_code2','geometry']]

# %%
# from previous runs - combined 2016 and 2019 ,'PYF_1992'
bad_adm1 = ['FSM_2','TLS_201', 'BHR_2229','CAN_2253',
            'MAR_502','RUS_391','RUS_421','RUS_443','RUS_453',
            'RUS_2252','USA_759','HND_2117','MAR_502', 'CAN_558']

# %% [markdown]
# ## Run for one country 2019

# %%
shp_name, flood_name = 'Afghanistan', 'afghanistan'

# %%
sub = adm.loc[adm['ADM0_NAME'] == shp_name].copy()

# Save country name
countryCode = sub['ISO3'].iloc[0]
countryNameInfo = pycountry.countries.get(alpha_3=countryCode)
tPrint(f'{countryCode}: {sub.shape[0]}') 

# Adm0 fluvial and pluvial processing
Fluvial_outputfile, Pluvial_outputfile = adm0_processing_2019(flood_name)

# # testing for one adm1 region
# sub = sub.iloc[[0]]
# Adm1 data processing loop:
result = adm1_loop(sub, result)

tPrint(f"{countryCode} - Completed")
# Out:
# 16:05:42	AFG: 34
# 16:05:45	AFG: Only one fluvial tile. No merge needed
# 16:05:51	AFG: Country level fluvial exported
# 16:05:55	AFG: Only one pluvial tile. No merge needed
# 16:06:02	AFG: Country level pluvial exported
# 16:06:03	AFG_1954 - Fluvial cropped to adm 1
# 16:06:05	AFG_1954 - Pluvial cropped to adm 1
# 16:06:09	AFG_1954 - popAligned aligned
# 16:06:10	AFG_1954 - Pop cropped to adm 1
# 16:06:11	AFG_1954 - Pop aligned & cropped. Total Pop: 1240509.0
# 16:06:12	AFG_1954 - AlignedCoastalFlood aligned
# 16:06:12	AFG_1954 - Coastal aligned
# 16:06:15	AFG_1954 - Flood mosaic merged & exported
# 16:06:16	AFG_1954 - FloodCropped cropped to adm 1
# 16:06:17	AFG_1954 - Confirming same shape. popArray shape: (1, 3661, 5886) floodArray shape: (1, 3661, 5886)
# 16:06:17	AFG_1954 - Flood categorized
# 16:06:18	AFG_1954 - Flood converted to bool int arrays
# 16:06:18	AFG_1954 - Flood multiplied by pop
# 16:06:24	AFG_1954 - Checksum: 1240504.875
# 16:06:24	AFG_1954 - Sums added to df
# C:\Users\bjafino\anaconda3\envs\GMTRA\lib\site-packages\ipykernel\__main__.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 16:06:24	AFG_1955 - Fluvial cropped to adm 1
# 16:06:25	AFG_1955 - Pluvial cropped to adm 1
# 16:06:26	AFG_1955 - popAligned aligned
# 16:06:26	AFG_1955 - Pop cropped to adm 1
# 16:06:27	AFG_1955 - Pop aligned & cropped. Total Pop: 655911.375
# 16:06:27	AFG_1955 - AlignedCoastalFlood aligned
# 16:06:27	AFG_1955 - Coastal aligned
# 16:06:28	AFG_1955 - Flood mosaic merged & exported
# 16:06:28	AFG_1955 - FloodCropped cropped to adm 1
# 16:06:28	AFG_1955 - Confirming same shape. popArray shape: (1, 1819, 2867) floodArray shape: (1, 1819, 2867)
# 16:06:28	AFG_1955 - Flood categorized
# 16:06:28	AFG_1955 - Flood converted to bool int arrays
# 16:06:29	AFG_1955 - Flood multiplied by pop
# 16:06:30	AFG_1955 - Checksum: 655910.6875
# 16:06:30	AFG_1955 - Sums added to df
# 16:06:31	AFG_1956 - Fluvial cropped to adm 1
# 16:06:31	AFG_1956 - Pluvial cropped to adm 1
# 16:06:32	AFG_1956 - popAligned aligned
# 16:06:33	AFG_1956 - Pop cropped to adm 1
# 16:06:33	AFG_1956 - Pop aligned & cropped. Total Pop: 969238.625
# 16:06:33	AFG_1956 - AlignedCoastalFlood aligned
# 16:06:33	AFG_1956 - Coastal aligned
# 16:06:34	AFG_1956 - Flood mosaic merged & exported
# 16:06:34	AFG_1956 - FloodCropped cropped to adm 1
# 16:06:34	AFG_1956 - Confirming same shape. popArray shape: (1, 1886, 2360) floodArray shape: (1, 1886, 2360)
# 16:06:34	AFG_1956 - Flood categorized
# 16:06:34	AFG_1956 - Flood converted to bool int arrays
# 16:06:35	AFG_1956 - Flood multiplied by pop
# 16:06:36	AFG_1956 - Checksum: 969237.9375
# 16:06:36	AFG_1956 - Sums added to df
# 16:06:36	AFG_1957 - Fluvial cropped to adm 1
# 16:06:37	AFG_1957 - Pluvial cropped to adm 1
# 16:06:38	AFG_1957 - popAligned aligned
# 16:06:38	AFG_1957 - Pop cropped to adm 1
# 16:06:39	AFG_1957 - Pop aligned & cropped. Total Pop: 1309907.0
# 16:06:39	AFG_1957 - AlignedCoastalFlood aligned
# 16:06:39	AFG_1957 - Coastal aligned
# 16:06:40	AFG_1957 - Flood mosaic merged & exported
# 16:06:40	AFG_1957 - FloodCropped cropped to adm 1
# 16:06:40	AFG_1957 - Confirming same shape. popArray shape: (1, 2070, 2342) floodArray shape: (1, 2070, 2342)
# 16:06:40	AFG_1957 - Flood categorized
# 16:06:40	AFG_1957 - Flood converted to bool int arrays
# 16:06:41	AFG_1957 - Flood multiplied by pop
# 16:06:42	AFG_1957 - Checksum: 1309909.875
# 16:06:42	AFG_1957 - Sums added to df
# 16:06:42	AFG_1958 - Fluvial cropped to adm 1
# 16:06:43	AFG_1958 - Pluvial cropped to adm 1
# 16:06:44	AFG_1958 - popAligned aligned
# 16:06:44	AFG_1958 - Pop cropped to adm 1
# 16:06:45	AFG_1958 - Pop aligned & cropped. Total Pop: 511421.59375
# 16:06:45	AFG_1958 - AlignedCoastalFlood aligned
# 16:06:45	AFG_1958 - Coastal aligned
# 16:06:46	AFG_1958 - Flood mosaic merged & exported
# 16:06:46	AFG_1958 - FloodCropped cropped to adm 1
# 16:06:46	AFG_1958 - Confirming same shape. popArray shape: (1, 1888, 2363) floodArray shape: (1, 1888, 2363)
# 16:06:46	AFG_1958 - Flood categorized
# 16:06:46	AFG_1958 - Flood converted to bool int arrays
# 16:06:46	AFG_1958 - Flood multiplied by pop
# 16:06:48	AFG_1958 - Checksum: 511421.125
# 16:06:48	AFG_1958 - Sums added to df
# 16:06:48	AFG_1959 - Fluvial cropped to adm 1
# 16:06:49	AFG_1959 - Pluvial cropped to adm 1
# 16:06:52	AFG_1959 - popAligned aligned
# 16:06:52	AFG_1959 - Pop cropped to adm 1
# 16:06:53	AFG_1959 - Pop aligned & cropped. Total Pop: 628339.5
# 16:06:54	AFG_1959 - AlignedCoastalFlood aligned
# 16:06:54	AFG_1959 - Coastal aligned
# 16:06:56	AFG_1959 - Flood mosaic merged & exported
# 16:06:56	AFG_1959 - FloodCropped cropped to adm 1
# 16:06:57	AFG_1959 - Confirming same shape. popArray shape: (1, 2559, 4977) floodArray shape: (1, 2559, 4977)
# 16:06:57	AFG_1959 - Flood categorized
# 16:06:57	AFG_1959 - Flood converted to bool int arrays
# 16:06:58	AFG_1959 - Flood multiplied by pop
# 16:07:01	AFG_1959 - Checksum: 628339.5
# 16:07:01	AFG_1959 - Sums added to df
# 16:07:01	AFG_1960 - Fluvial cropped to adm 1
# 16:07:02	AFG_1960 - Pluvial cropped to adm 1
# 16:07:03	AFG_1960 - popAligned aligned
# 16:07:04	AFG_1960 - Pop cropped to adm 1
# 16:07:04	AFG_1960 - Pop aligned & cropped. Total Pop: 1199512.375
# 16:07:04	AFG_1960 - AlignedCoastalFlood aligned
# 16:07:04	AFG_1960 - Coastal aligned
# 16:07:05	AFG_1960 - Flood mosaic merged & exported
# 16:07:05	AFG_1960 - FloodCropped cropped to adm 1
# 16:07:06	AFG_1960 - Confirming same shape. popArray shape: (1, 2506, 2313) floodArray shape: (1, 2506, 2313)
# 16:07:06	AFG_1960 - Flood categorized
# 16:07:06	AFG_1960 - Flood converted to bool int arrays
# 16:07:06	AFG_1960 - Flood multiplied by pop
# 16:07:08	AFG_1960 - Checksum: 1199513.875
# 16:07:08	AFG_1960 - Sums added to df
# 16:07:08	AFG_1961 - Fluvial cropped to adm 1
# 16:07:09	AFG_1961 - Pluvial cropped to adm 1
# 16:07:11	AFG_1961 - popAligned aligned
# 16:07:11	AFG_1961 - Pop cropped to adm 1
# 16:07:11	AFG_1961 - Pop aligned & cropped. Total Pop: 855979.8125
# 16:07:12	AFG_1961 - AlignedCoastalFlood aligned
# 16:07:12	AFG_1961 - Coastal aligned
# 16:07:13	AFG_1961 - Flood mosaic merged & exported
# 16:07:13	AFG_1961 - FloodCropped cropped to adm 1
# 16:07:13	AFG_1961 - Confirming same shape. popArray shape: (1, 2575, 2406) floodArray shape: (1, 2575, 2406)
# 16:07:13	AFG_1961 - Flood categorized
# 16:07:14	AFG_1961 - Flood converted to bool int arrays
# 16:07:14	AFG_1961 - Flood multiplied by pop
# 16:07:15	AFG_1961 - Checksum: 855978.8125
# 16:07:16	AFG_1961 - Sums added to df
# 16:07:16	AFG_1962 - Fluvial cropped to adm 1
# 16:07:17	AFG_1962 - Pluvial cropped to adm 1
# 16:07:20	AFG_1962 - popAligned aligned
# 16:07:20	AFG_1962 - Pop cropped to adm 1
# 16:07:21	AFG_1962 - Pop aligned & cropped. Total Pop: 830182.9375
# 16:07:21	AFG_1962 - AlignedCoastalFlood aligned
# 16:07:21	AFG_1962 - Coastal aligned
# 16:07:23	AFG_1962 - Flood mosaic merged & exported
# 16:07:24	AFG_1962 - FloodCropped cropped to adm 1
# 16:07:24	AFG_1962 - Confirming same shape. popArray shape: (1, 2587, 4237) floodArray shape: (1, 2587, 4237)
# 16:07:24	AFG_1962 - Flood categorized
# 16:07:24	AFG_1962 - Flood converted to bool int arrays
# 16:07:25	AFG_1962 - Flood multiplied by pop
# 16:07:28	AFG_1962 - Checksum: 830183.8125
# 16:07:28	AFG_1962 - Sums added to df
# 16:07:29	AFG_1963 - Fluvial cropped to adm 1
# 16:07:30	AFG_1963 - Pluvial cropped to adm 1
# 16:07:35	AFG_1963 - popAligned aligned
# 16:07:36	AFG_1963 - Pop cropped to adm 1
# 16:07:37	AFG_1963 - Pop aligned & cropped. Total Pop: 1019291.5
# 16:07:38	AFG_1963 - AlignedCoastalFlood aligned
# 16:07:38	AFG_1963 - Coastal aligned
# 16:07:41	AFG_1963 - Flood mosaic merged & exported
# 16:07:42	AFG_1963 - FloodCropped cropped to adm 1
# 16:07:42	AFG_1963 - Confirming same shape. popArray shape: (1, 5160, 3755) floodArray shape: (1, 5160, 3755)
# 16:07:43	AFG_1963 - Flood categorized
# 16:07:43	AFG_1963 - Flood converted to bool int arrays
# 16:07:44	AFG_1963 - Flood multiplied by pop
# 16:07:49	AFG_1963 - Checksum: 1019290.0
# 16:07:49	AFG_1963 - Sums added to df
# 16:07:50	AFG_1964 - Fluvial cropped to adm 1
# 16:07:51	AFG_1964 - Pluvial cropped to adm 1
# 16:07:55	AFG_1964 - popAligned aligned
# 16:07:55	AFG_1964 - Pop cropped to adm 1
# 16:07:56	AFG_1964 - Pop aligned & cropped. Total Pop: 2408163.75
# 16:07:57	AFG_1964 - AlignedCoastalFlood aligned
# 16:07:57	AFG_1964 - Coastal aligned
# 16:08:00	AFG_1964 - Flood mosaic merged & exported
# 16:08:00	AFG_1964 - FloodCropped cropped to adm 1
# 16:08:01	AFG_1964 - Confirming same shape. popArray shape: (1, 3331, 4804) floodArray shape: (1, 3331, 4804)
# 16:08:01	AFG_1964 - Flood categorized
# 16:08:01	AFG_1964 - Flood converted to bool int arrays
# 16:08:02	AFG_1964 - Flood multiplied by pop
# 16:08:06	AFG_1964 - Checksum: 2408180.5
# 16:08:06	AFG_1964 - Sums added to df
# 16:08:06	AFG_1965 - Fluvial cropped to adm 1
# 16:08:07	AFG_1965 - Pluvial cropped to adm 1
# 16:08:08	AFG_1965 - popAligned aligned
# 16:08:08	AFG_1965 - Pop cropped to adm 1
# 16:08:08	AFG_1965 - Pop aligned & cropped. Total Pop: 523100.5625
# 16:08:08	AFG_1965 - AlignedCoastalFlood aligned
# 16:08:08	AFG_1965 - Coastal aligned
# 16:08:09	AFG_1965 - Flood mosaic merged & exported
# 16:08:09	AFG_1965 - FloodCropped cropped to adm 1
# 16:08:09	AFG_1965 - Confirming same shape. popArray shape: (1, 1972, 1685) floodArray shape: (1, 1972, 1685)
# 16:08:09	AFG_1965 - Flood categorized
# 16:08:09	AFG_1965 - Flood converted to bool int arrays
# 16:08:10	AFG_1965 - Flood multiplied by pop
# 16:08:11	AFG_1965 - Checksum: 523100.625
# 16:08:11	AFG_1965 - Sums added to df
# 16:08:11	AFG_1966 - Fluvial cropped to adm 1
# 16:08:11	AFG_1966 - Pluvial cropped to adm 1
# 16:08:11	AFG_1966 - popAligned aligned
# 16:08:12	AFG_1966 - Pop cropped to adm 1
# 16:08:12	AFG_1966 - Pop aligned & cropped. Total Pop: 4819151.5
# 16:08:12	AFG_1966 - AlignedCoastalFlood aligned
# 16:08:12	AFG_1966 - Coastal aligned
# 16:08:12	AFG_1966 - Flood mosaic merged & exported
# 16:08:12	AFG_1966 - FloodCropped cropped to adm 1
# 16:08:12	AFG_1966 - Confirming same shape. popArray shape: (1, 942, 1343) floodArray shape: (1, 942, 1343)
# 16:08:12	AFG_1966 - Flood categorized
# 16:08:12	AFG_1966 - Flood converted to bool int arrays
# 16:08:12	AFG_1966 - Flood multiplied by pop
# 16:08:13	AFG_1966 - Checksum: 4819153.5
# 16:08:13	AFG_1966 - Sums added to df
# 16:08:13	AFG_1967 - Fluvial cropped to adm 1
# 16:08:14	AFG_1967 - Pluvial cropped to adm 1
# 16:08:17	AFG_1967 - popAligned aligned
# 16:08:18	AFG_1967 - Pop cropped to adm 1
# 16:08:19	AFG_1967 - Pop aligned & cropped. Total Pop: 1419176.875
# 16:08:20	AFG_1967 - AlignedCoastalFlood aligned
# 16:08:20	AFG_1967 - Coastal aligned
# 16:08:22	AFG_1967 - Flood mosaic merged & exported
# 16:08:23	AFG_1967 - FloodCropped cropped to adm 1
# 16:08:23	AFG_1967 - Confirming same shape. popArray shape: (1, 3672, 3953) floodArray shape: (1, 3672, 3953)
# 16:08:23	AFG_1967 - Flood categorized
# 16:08:24	AFG_1967 - Flood converted to bool int arrays
# 16:08:24	AFG_1967 - Flood multiplied by pop
# 16:08:28	AFG_1967 - Checksum: 1419171.625
# 16:08:28	AFG_1967 - Sums added to df
# 16:08:28	AFG_1968 - Fluvial cropped to adm 1
# 16:08:28	AFG_1968 - Pluvial cropped to adm 1
# 16:08:29	AFG_1968 - popAligned aligned
# 16:08:29	AFG_1968 - Pop cropped to adm 1
# 16:08:29	AFG_1968 - Pop aligned & cropped. Total Pop: 478039.90625
# 16:08:29	AFG_1968 - AlignedCoastalFlood aligned
# 16:08:29	AFG_1968 - Coastal aligned
# 16:08:29	AFG_1968 - Flood mosaic merged & exported
# 16:08:29	AFG_1968 - FloodCropped cropped to adm 1
# 16:08:29	AFG_1968 - Confirming same shape. popArray shape: (1, 664, 782) floodArray shape: (1, 664, 782)
# 16:08:29	AFG_1968 - Flood categorized
# 16:08:29	AFG_1968 - Flood converted to bool int arrays
# 16:08:29	AFG_1968 - Flood multiplied by pop
# 16:08:29	AFG_1968 - Checksum: 478039.46875
# 16:08:30	AFG_1968 - Sums added to df
# 16:08:30	AFG_1969 - Fluvial cropped to adm 1
# 16:08:30	AFG_1969 - Pluvial cropped to adm 1
# 16:08:30	AFG_1969 - popAligned aligned
# 16:08:30	AFG_1969 - Pop cropped to adm 1
# 16:08:31	AFG_1969 - Pop aligned & cropped. Total Pop: 836790.625
# 16:08:31	AFG_1969 - AlignedCoastalFlood aligned
# 16:08:31	AFG_1969 - Coastal aligned
# 16:08:31	AFG_1969 - Flood mosaic merged & exported
# 16:08:31	AFG_1969 - FloodCropped cropped to adm 1
# 16:08:31	AFG_1969 - Confirming same shape. popArray shape: (1, 873, 1173) floodArray shape: (1, 873, 1173)
# 16:08:31	AFG_1969 - Flood categorized
# 16:08:31	AFG_1969 - Flood converted to bool int arrays
# 16:08:31	AFG_1969 - Flood multiplied by pop
# 16:08:31	AFG_1969 - Checksum: 836790.3125
# 16:08:31	AFG_1969 - Sums added to df
# 16:08:31	AFG_1970 - Fluvial cropped to adm 1
# 16:08:32	AFG_1970 - Pluvial cropped to adm 1
# 16:08:32	AFG_1970 - popAligned aligned
# 16:08:33	AFG_1970 - Pop cropped to adm 1
# 16:08:33	AFG_1970 - Pop aligned & cropped. Total Pop: 521366.84375
# 16:08:33	AFG_1970 - AlignedCoastalFlood aligned
# 16:08:33	AFG_1970 - Coastal aligned
# 16:08:33	AFG_1970 - Flood mosaic merged & exported
# 16:08:33	AFG_1970 - FloodCropped cropped to adm 1
# 16:08:33	AFG_1970 - Confirming same shape. popArray shape: (1, 1151, 1327) floodArray shape: (1, 1151, 1327)
# 16:08:33	AFG_1970 - Flood categorized
# 16:08:33	AFG_1970 - Flood converted to bool int arrays
# 16:08:33	AFG_1970 - Flood multiplied by pop
# 16:08:34	AFG_1970 - Checksum: 521367.34375
# 16:08:34	AFG_1970 - Sums added to df
# 16:08:34	AFG_1971 - Fluvial cropped to adm 1
# 16:08:34	AFG_1971 - Pluvial cropped to adm 1
# 16:08:35	AFG_1971 - popAligned aligned
# 16:08:35	AFG_1971 - Pop cropped to adm 1
# 16:08:35	AFG_1971 - Pop aligned & cropped. Total Pop: 900686.25
# 16:08:35	AFG_1971 - AlignedCoastalFlood aligned
# 16:08:35	AFG_1971 - Coastal aligned
# 16:08:36	AFG_1971 - Flood mosaic merged & exported
# 16:08:36	AFG_1971 - FloodCropped cropped to adm 1
# 16:08:36	AFG_1971 - Confirming same shape. popArray shape: (1, 1214, 1588) floodArray shape: (1, 1214, 1588)
# 16:08:36	AFG_1971 - Flood categorized
# 16:08:36	AFG_1971 - Flood converted to bool int arrays
# 16:08:36	AFG_1971 - Flood multiplied by pop
# 16:08:37	AFG_1971 - Checksum: 900686.4375
# 16:08:37	AFG_1971 - Sums added to df
# 16:08:37	AFG_1972 - Fluvial cropped to adm 1
# 16:08:37	AFG_1972 - Pluvial cropped to adm 1
# 16:08:38	AFG_1972 - popAligned aligned
# 16:08:38	AFG_1972 - Pop cropped to adm 1
# 16:08:38	AFG_1972 - Pop aligned & cropped. Total Pop: 539003.25
# 16:08:38	AFG_1972 - AlignedCoastalFlood aligned
# 16:08:38	AFG_1972 - Coastal aligned
# 16:08:38	AFG_1972 - Flood mosaic merged & exported
# 16:08:38	AFG_1972 - FloodCropped cropped to adm 1
# 16:08:38	AFG_1972 - Confirming same shape. popArray shape: (1, 966, 986) floodArray shape: (1, 966, 986)
# 16:08:38	AFG_1972 - Flood categorized
# 16:08:38	AFG_1972 - Flood converted to bool int arrays
# 16:08:38	AFG_1972 - Flood multiplied by pop
# 16:08:38	AFG_1972 - Checksum: 539003.125
# 16:08:39	AFG_1972 - Sums added to df
# 16:08:39	AFG_1973 - Fluvial cropped to adm 1
# 16:08:39	AFG_1973 - Pluvial cropped to adm 1
# 16:08:39	AFG_1973 - popAligned aligned
# 16:08:40	AFG_1973 - Pop cropped to adm 1
# 16:08:40	AFG_1973 - Pop aligned & cropped. Total Pop: 453283.15625
# 16:08:40	AFG_1973 - AlignedCoastalFlood aligned
# 16:08:40	AFG_1973 - Coastal aligned
# 16:08:40	AFG_1973 - Flood mosaic merged & exported
# 16:08:40	AFG_1973 - FloodCropped cropped to adm 1
# 16:08:40	AFG_1973 - Confirming same shape. popArray shape: (1, 929, 1432) floodArray shape: (1, 929, 1432)
# 16:08:40	AFG_1973 - Flood categorized
# 16:08:40	AFG_1973 - Flood converted to bool int arrays
# 16:08:40	AFG_1973 - Flood multiplied by pop
# 16:08:41	AFG_1973 - Checksum: 453283.15625
# 16:08:41	AFG_1973 - Sums added to df
# 16:08:41	AFG_1974 - Fluvial cropped to adm 1
# 16:08:41	AFG_1974 - Pluvial cropped to adm 1
# 16:08:42	AFG_1974 - popAligned aligned
# 16:08:42	AFG_1974 - Pop cropped to adm 1
# 16:08:42	AFG_1974 - Pop aligned & cropped. Total Pop: 1772137.125
# 16:08:43	AFG_1974 - AlignedCoastalFlood aligned
# 16:08:43	AFG_1974 - Coastal aligned
# 16:08:43	AFG_1974 - Flood mosaic merged & exported
# 16:08:43	AFG_1974 - FloodCropped cropped to adm 1
# 16:08:43	AFG_1974 - Confirming same shape. popArray shape: (1, 1041, 2038) floodArray shape: (1, 1041, 2038)
# 16:08:43	AFG_1974 - Flood categorized
# 16:08:43	AFG_1974 - Flood converted to bool int arrays
# 16:08:43	AFG_1974 - Flood multiplied by pop
# 16:08:44	AFG_1974 - Checksum: 1772138.375
# 16:08:44	AFG_1974 - Sums added to df
# 16:08:44	AFG_1975 - Fluvial cropped to adm 1
# 16:08:45	AFG_1975 - Pluvial cropped to adm 1
# 16:08:48	AFG_1975 - popAligned aligned
# 16:08:49	AFG_1975 - Pop cropped to adm 1
# 16:08:50	AFG_1975 - Pop aligned & cropped. Total Pop: 165084.328125
# 16:08:50	AFG_1975 - AlignedCoastalFlood aligned
# 16:08:50	AFG_1975 - Coastal aligned
# 16:08:52	AFG_1975 - Flood mosaic merged & exported
# 16:08:52	AFG_1975 - FloodCropped cropped to adm 1
# 16:08:53	AFG_1975 - Confirming same shape. popArray shape: (1, 3447, 3216) floodArray shape: (1, 3447, 3216)
# 16:08:53	AFG_1975 - Flood categorized
# 16:08:53	AFG_1975 - Flood converted to bool int arrays
# 16:08:54	AFG_1975 - Flood multiplied by pop
# 16:08:57	AFG_1975 - Checksum: 165084.140625
# 16:08:57	AFG_1975 - Sums added to df
# 16:08:57	AFG_1976 - Fluvial cropped to adm 1
# 16:08:57	AFG_1976 - Pluvial cropped to adm 1
# 16:08:59	AFG_1976 - popAligned aligned
# 16:08:59	AFG_1976 - Pop cropped to adm 1
# 16:08:59	AFG_1976 - Pop aligned & cropped. Total Pop: 169556.484375
# 16:08:59	AFG_1976 - AlignedCoastalFlood aligned
# 16:08:59	AFG_1976 - Coastal aligned
# 16:09:00	AFG_1976 - Flood mosaic merged & exported
# 16:09:00	AFG_1976 - FloodCropped cropped to adm 1
# 16:09:00	AFG_1976 - Confirming same shape. popArray shape: (1, 1348, 2051) floodArray shape: (1, 1348, 2051)
# 16:09:00	AFG_1976 - Flood categorized
# 16:09:00	AFG_1976 - Flood converted to bool int arrays
# 16:09:00	AFG_1976 - Flood multiplied by pop
# 16:09:01	AFG_1976 - Checksum: 169556.484375
# 16:09:01	AFG_1976 - Sums added to df
# 16:09:01	AFG_1977 - Fluvial cropped to adm 1
# 16:09:02	AFG_1977 - Pluvial cropped to adm 1
# 16:09:03	AFG_1977 - popAligned aligned
# 16:09:04	AFG_1977 - Pop cropped to adm 1
# 16:09:04	AFG_1977 - Pop aligned & cropped. Total Pop: 471931.25
# 16:09:04	AFG_1977 - AlignedCoastalFlood aligned
# 16:09:04	AFG_1977 - Coastal aligned
# 16:09:05	AFG_1977 - Flood mosaic merged & exported
# 16:09:05	AFG_1977 - FloodCropped cropped to adm 1
# 16:09:06	AFG_1977 - Confirming same shape. popArray shape: (1, 2193, 2083) floodArray shape: (1, 2193, 2083)
# 16:09:06	AFG_1977 - Flood categorized
# 16:09:06	AFG_1977 - Flood converted to bool int arrays
# 16:09:06	AFG_1977 - Flood multiplied by pop
# 16:09:07	AFG_1977 - Checksum: 471931.0
# 16:09:07	AFG_1977 - Sums added to df
# 16:09:07	AFG_1978 - Fluvial cropped to adm 1
# 16:09:08	AFG_1978 - Pluvial cropped to adm 1
# 16:09:08	AFG_1978 - popAligned aligned
# 16:09:09	AFG_1978 - Pop cropped to adm 1
# 16:09:09	AFG_1978 - Pop aligned & cropped. Total Pop: 626945.1875
# 16:09:09	AFG_1978 - AlignedCoastalFlood aligned
# 16:09:09	AFG_1978 - Coastal aligned
# 16:09:09	AFG_1978 - Flood mosaic merged & exported
# 16:09:09	AFG_1978 - FloodCropped cropped to adm 1
# 16:09:09	AFG_1978 - Confirming same shape. popArray shape: (1, 1122, 1500) floodArray shape: (1, 1122, 1500)
# 16:09:09	AFG_1978 - Flood categorized
# 16:09:09	AFG_1978 - Flood converted to bool int arrays
# 16:09:09	AFG_1978 - Flood multiplied by pop
# 16:09:10	AFG_1978 - Checksum: 626944.9375
# 16:09:10	AFG_1978 - Sums added to df
# 16:09:10	AFG_1979 - Fluvial cropped to adm 1
# 16:09:10	AFG_1979 - Pluvial cropped to adm 1
# 16:09:11	AFG_1979 - popAligned aligned
# 16:09:12	AFG_1979 - Pop cropped to adm 1
# 16:09:12	AFG_1979 - Pop aligned & cropped. Total Pop: 430320.5
# 16:09:12	AFG_1979 - AlignedCoastalFlood aligned
# 16:09:12	AFG_1979 - Coastal aligned
# 16:09:12	AFG_1979 - Flood mosaic merged & exported
# 16:09:13	AFG_1979 - FloodCropped cropped to adm 1
# 16:09:13	AFG_1979 - Confirming same shape. popArray shape: (1, 1548, 1997) floodArray shape: (1, 1548, 1997)
# 16:09:13	AFG_1979 - Flood categorized
# 16:09:13	AFG_1979 - Flood converted to bool int arrays
# 16:09:13	AFG_1979 - Flood multiplied by pop
# 16:09:14	AFG_1979 - Checksum: 430319.90625
# 16:09:14	AFG_1979 - Sums added to df
# 16:09:14	AFG_1980 - Fluvial cropped to adm 1
# 16:09:14	AFG_1980 - Pluvial cropped to adm 1
# 16:09:16	AFG_1980 - popAligned aligned
# 16:09:16	AFG_1980 - Pop cropped to adm 1
# 16:09:17	AFG_1980 - Pop aligned & cropped. Total Pop: 600296.125
# 16:09:17	AFG_1980 - AlignedCoastalFlood aligned
# 16:09:17	AFG_1980 - Coastal aligned
# 16:09:17	AFG_1980 - Flood mosaic merged & exported
# 16:09:18	AFG_1980 - FloodCropped cropped to adm 1
# 16:09:18	AFG_1980 - Confirming same shape. popArray shape: (1, 2045, 1978) floodArray shape: (1, 2045, 1978)
# 16:09:18	AFG_1980 - Flood categorized
# 16:09:18	AFG_1980 - Flood converted to bool int arrays
# 16:09:18	AFG_1980 - Flood multiplied by pop
# 16:09:19	AFG_1980 - Checksum: 600295.5625
# 16:09:19	AFG_1980 - Sums added to df
# 16:09:19	AFG_1981 - Fluvial cropped to adm 1
# 16:09:20	AFG_1981 - Pluvial cropped to adm 1
# 16:09:21	AFG_1981 - popAligned aligned
# 16:09:21	AFG_1981 - Pop cropped to adm 1
# 16:09:22	AFG_1981 - Pop aligned & cropped. Total Pop: 1169614.5
# 16:09:22	AFG_1981 - AlignedCoastalFlood aligned
# 16:09:22	AFG_1981 - Coastal aligned
# 16:09:22	AFG_1981 - Flood mosaic merged & exported
# 16:09:23	AFG_1981 - FloodCropped cropped to adm 1
# 16:09:23	AFG_1981 - Confirming same shape. popArray shape: (1, 2201, 1572) floodArray shape: (1, 2201, 1572)
# 16:09:23	AFG_1981 - Flood categorized
# 16:09:23	AFG_1981 - Flood converted to bool int arrays
# 16:09:23	AFG_1981 - Flood multiplied by pop
# 16:09:24	AFG_1981 - Checksum: 1169615.375
# 16:09:24	AFG_1981 - Sums added to df
# 16:09:24	AFG_1982 - Fluvial cropped to adm 1
# 16:09:24	AFG_1982 - Pluvial cropped to adm 1
# 16:09:26	AFG_1982 - popAligned aligned
# 16:09:26	AFG_1982 - Pop cropped to adm 1
# 16:09:26	AFG_1982 - Pop aligned & cropped. Total Pop: 723670.375
# 16:09:26	AFG_1982 - AlignedCoastalFlood aligned
# 16:09:26	AFG_1982 - Coastal aligned
# 16:09:27	AFG_1982 - Flood mosaic merged & exported
# 16:09:27	AFG_1982 - FloodCropped cropped to adm 1
# 16:09:27	AFG_1982 - Confirming same shape. popArray shape: (1, 1344, 2100) floodArray shape: (1, 1344, 2100)
# 16:09:27	AFG_1982 - Flood categorized
# 16:09:27	AFG_1982 - Flood converted to bool int arrays
# 16:09:27	AFG_1982 - Flood multiplied by pop
# 16:09:28	AFG_1982 - Checksum: 723670.625
# 16:09:28	AFG_1982 - Sums added to df
# 16:09:28	AFG_1983 - Fluvial cropped to adm 1
# 16:09:29	AFG_1983 - Pluvial cropped to adm 1
# 16:09:30	AFG_1983 - popAligned aligned
# 16:09:30	AFG_1983 - Pop cropped to adm 1
# 16:09:31	AFG_1983 - Pop aligned & cropped. Total Pop: 330254.28125
# 16:09:31	AFG_1983 - AlignedCoastalFlood aligned
# 16:09:31	AFG_1983 - Coastal aligned
# 16:09:32	AFG_1983 - Flood mosaic merged & exported
# 16:09:32	AFG_1983 - FloodCropped cropped to adm 1
# 16:09:32	AFG_1983 - Confirming same shape. popArray shape: (1, 1894, 2317) floodArray shape: (1, 1894, 2317)
# 16:09:32	AFG_1983 - Flood categorized
# 16:09:32	AFG_1983 - Flood converted to bool int arrays
# 16:09:32	AFG_1983 - Flood multiplied by pop
# 16:09:34	AFG_1983 - Checksum: 330254.375
# 16:09:34	AFG_1983 - Sums added to df
# 16:09:34	AFG_1984 - Fluvial cropped to adm 1
# 16:09:34	AFG_1984 - Pluvial cropped to adm 1
# 16:09:36	AFG_1984 - popAligned aligned
# 16:09:36	AFG_1984 - Pop cropped to adm 1
# 16:09:36	AFG_1984 - Pop aligned & cropped. Total Pop: 489368.0625
# 16:09:36	AFG_1984 - AlignedCoastalFlood aligned
# 16:09:36	AFG_1984 - Coastal aligned
# 16:09:37	AFG_1984 - Flood mosaic merged & exported
# 16:09:37	AFG_1984 - FloodCropped cropped to adm 1
# 16:09:38	AFG_1984 - Confirming same shape. popArray shape: (1, 1731, 2492) floodArray shape: (1, 1731, 2492)
# 16:09:38	AFG_1984 - Flood categorized
# 16:09:38	AFG_1984 - Flood converted to bool int arrays
# 16:09:38	AFG_1984 - Flood multiplied by pop
# 16:09:39	AFG_1984 - Checksum: 489367.96875
# 16:09:39	AFG_1984 - Sums added to df
# 16:09:39	AFG_1985 - Fluvial cropped to adm 1
# 16:09:39	AFG_1985 - Pluvial cropped to adm 1
# 16:09:40	AFG_1985 - popAligned aligned
# 16:09:40	AFG_1985 - Pop cropped to adm 1
# 16:09:40	AFG_1985 - Pop aligned & cropped. Total Pop: 157087.984375
# 16:09:40	AFG_1985 - AlignedCoastalFlood aligned
# 16:09:40	AFG_1985 - Coastal aligned
# 16:09:40	AFG_1985 - Flood mosaic merged & exported
# 16:09:41	AFG_1985 - FloodCropped cropped to adm 1
# 16:09:41	AFG_1985 - Confirming same shape. popArray shape: (1, 979, 1264) floodArray shape: (1, 979, 1264)
# 16:09:41	AFG_1985 - Flood categorized
# 16:09:41	AFG_1985 - Flood converted to bool int arrays
# 16:09:41	AFG_1985 - Flood multiplied by pop
# 16:09:41	AFG_1985 - Checksum: 157087.890625
# 16:09:41	AFG_1985 - Sums added to df
# 16:09:41	AFG_1986 - Fluvial cropped to adm 1
# 16:09:41	AFG_1986 - Pluvial cropped to adm 1
# 16:09:42	AFG_1986 - popAligned aligned
# 16:09:42	AFG_1986 - Pop cropped to adm 1
# 16:09:42	AFG_1986 - Pop aligned & cropped. Total Pop: 681830.4375
# 16:09:42	AFG_1986 - AlignedCoastalFlood aligned
# 16:09:42	AFG_1986 - Coastal aligned
# 16:09:43	AFG_1986 - Flood mosaic merged & exported
# 16:09:43	AFG_1986 - FloodCropped cropped to adm 1
# 16:09:43	AFG_1986 - Confirming same shape. popArray shape: (1, 1006, 1722) floodArray shape: (1, 1006, 1722)
# 16:09:43	AFG_1986 - Flood categorized
# 16:09:43	AFG_1986 - Flood converted to bool int arrays
# 16:09:43	AFG_1986 - Flood multiplied by pop
# 16:09:44	AFG_1986 - Checksum: 681830.1875
# 16:09:44	AFG_1986 - Sums added to df
# 16:09:44	AFG_1987 - Fluvial cropped to adm 1
# 16:09:44	AFG_1987 - Pluvial cropped to adm 1
# 16:09:45	AFG_1987 - popAligned aligned
# 16:09:45	AFG_1987 - Pop cropped to adm 1
# 16:09:45	AFG_1987 - Pop aligned & cropped. Total Pop: 389167.96875
# 16:09:46	AFG_1987 - AlignedCoastalFlood aligned
# 16:09:46	AFG_1987 - Coastal aligned
# 16:09:46	AFG_1987 - Flood mosaic merged & exported
# 16:09:46	AFG_1987 - FloodCropped cropped to adm 1
# 16:09:46	AFG_1987 - Confirming same shape. popArray shape: (1, 1285, 2226) floodArray shape: (1, 1285, 2226)
# 16:09:46	AFG_1987 - Flood categorized
# 16:09:46	AFG_1987 - Flood converted to bool int arrays
# 16:09:47	AFG_1987 - Flood multiplied by pop
# 16:09:47	AFG_1987 - Checksum: 389168.125
# 16:09:47	AFG_1987 - Sums added to df
# 16:09:48	AFG - Completed

# %% [markdown]
# ## Run in loop

# %%
# 2019 bad countries - add ISO3 country code for any country that causes an issue
bad_countries_2019 = ['ABW','MDV','MHL','PYF','SYC','TUV','WSM'] #from Jun, old
bad_countries_2019 = ['ARG', 'ABW', 'ASM', 'BHR', 'BMU']
# from previous runs - combined 2016 and 2019 ,'PYF_1992'
bad_adm1 = ['CAN_2253']

# %%
try:
    result = pd.read_csv('Outputs/Results/temporary_results.csv', index_col=0)
except:
    pass

result.head()
# Out:
#       0-NoRiskPop  1-LowRiskPop  2-ModerateRiskPop  3-HighRiskPop  \
# 1954   1051159.88      78725.62           45188.55       24185.02
# 1955    570429.44      36018.29           23511.16       16800.77
# 1956    682697.88     129411.83           76251.77       42780.76
# 1957    953413.94     250442.92           67991.07       17319.62
# 1958    455034.75      19323.88           14031.10       12753.71
#
#       4-VeryHighRiskPop  5-WaterBodyPop ISO3
# 1954           40912.47          335.94  AFG
# 1955            9149.48            1.88  AFG
# 1956           38095.40            1.16  AFG
# 1957           19837.15          902.66  AFG
# 1958           10271.88            5.93  AFG

# %%
for shp_name, flood_name in matching_dict_2019.items():  
    if flood_name == "not_found":
#         None
        print(f"{shp_name} does not have flood data==================================")
    elif type(flood_name) == list and not flood_name == ['Fiji_east', 'Fiji_west']:
        print(f"{shp_name} has multiple datasets, need to investigate")
    else:
        # Skip processed countries
        processedCountries = result['ISO3'].unique()
        processedCountries = np.append(processedCountries, previouslyProcessed)

        sub = adm.loc[adm['ADM0_NAME'] == shp_name].copy()
        countryCode = sub['ISO3'].iloc[0]
        countryNameInfo = pycountry.countries.get(alpha_3=countryCode)
        
        if not countryCode in processedCountries and not countryCode in bad_countries_2019:
            tPrint(f'{countryCode}: {sub.shape[0]}') # start

            # Adm0 fluvial and pluvial processing
            Fluvial_outputfile, Pluvial_outputfile = adm0_processing_2019(flood_name)

            # Adm1 Loop:
            result = adm1_loop(sub, result)
            
            result.to_csv('Outputs/Results/temporary_results.csv')
                        
            tPrint(f"{countryCode} - Completed")  # end
        else:
            if countryCode in processedCountries:
                tPrint(f"{countryCode} already processed==================================")
# Out:
# 15:05:06	AFG already processed==================================
# 15:05:06	AGO already processed==================================
# 15:05:06	ALB already processed==================================
# 15:05:06	AND already processed==================================
# 15:05:06	ARE already processed==================================
# 15:05:06	ARM already processed==================================
# 15:05:06	ATG already processed==================================
# 15:05:06	AUS already processed==================================
# 15:05:06	AUT already processed==================================
# 15:05:06	AZE already processed==================================
# 15:05:06	BDI already processed==================================
# 15:05:06	BEL already processed==================================
# 15:05:06	BEN already processed==================================
# 15:05:06	BFA already processed==================================
# 15:05:06	BGD already processed==================================
# 15:05:06	BGR already processed==================================
# 15:05:06	BHS already processed==================================
# 15:05:06	BIH already processed==================================
# 15:05:06	BLR already processed==================================
# 15:05:06	BLZ already processed==================================
# 15:05:06	BOL already processed==================================
# 15:05:06	BRA already processed==================================
# 15:05:06	BRB already processed==================================
# 15:05:06	BRN already processed==================================
# 15:05:06	BTN already processed==================================
# 15:05:06	BWA already processed==================================
# 15:05:06	CAF already processed==================================
# 15:05:06	CAN: 13
# 15:08:21	CAN: Country level fluvial merged
# 15:11:02	CAN: Country level fluvial exported
# 15:14:53	CAN: Country level pluvial merged
# 15:17:54	CAN: Country level pluvial exported
# 15:17:57	Start processing CAN_548.
# C:\Users\bjafino\anaconda3\envs\GMTRA\lib\site-packages\ipykernel\__main__.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 15:24:02	CAN_548 - Sums added to df
# 15:24:03	Start processing CAN_549.
# 15:24:09	CAN_549 - Sums added to df
# 15:24:09	Start processing CAN_550.
# 15:25:03	CAN_550 - Sums added to df
# 15:25:03	Start processing CAN_551.
# 15:25:47	CAN_551 - Sums added to df
# 15:25:47	Start processing CAN_552.
# 15:37:40	CAN_552 - Sums added to df
# 15:37:42	Start processing CAN_553.
# 15:47:10	CAN_553 - Sums added to df
# 15:47:11	Start processing CAN_554.
# 15:52:03	CAN_554 - Sums added to df
# 15:52:04	Start processing CAN_555.
# 15:56:04	CAN_555 - Sums added to df
# 15:56:04	Start processing CAN_556.
# 16:00:14	CAN_556 - Sums added to df
# 16:00:14	Start processing CAN_557.
# 16:08:40	CAN_557 - Sums added to df
# 16:08:41	CAN_2253 is bad
# 16:08:41	Start processing CAN_2254.
# 16:22:30	CAN_2254 - adm1 memory error
# 16:22:35	Start processing CAN_2255.
# 16:27:45	CAN_2255 - Sums added to df
# 16:27:47	CAN - Completed
# 16:27:47	CHE: 7
# 16:27:47	CHE: Only one fluvial tile. No merge needed
# 16:27:47	CHE: Country level fluvial exported
# 16:27:48	CHE: Only one pluvial tile. No merge needed
# 16:27:48	CHE: Country level pluvial exported
# 16:27:48	Start processing CHE_234.
# 16:27:52	CHE_234 - Sums added to df
# 16:27:53	Start processing CHE_235.
# 16:27:56	CHE_235 - Sums added to df
# 16:27:56	Start processing CHE_236.
# 16:27:57	CHE_236 - Sums added to df
# 16:27:57	Start processing CHE_237.
# 16:27:58	CHE_237 - Sums added to df
# 16:27:58	Start processing CHE_238.
# 16:28:03	CHE_238 - Sums added to df
# 16:28:03	Start processing CHE_239.
# 16:28:05	CHE_239 - Sums added to df
# 16:28:05	Start processing CHE_240.
# 16:28:06	CHE_240 - Sums added to df
# 16:28:06	CHE - Completed
# 16:28:06	CHL: 16
# 16:29:30	CHL: Country level fluvial merged
# 16:30:36	CHL: Country level fluvial exported
# 16:31:46	CHL: Country level pluvial merged
# 16:32:50	CHL: Country level pluvial exported
# 16:32:52	Start processing CHL_208.
# 16:33:02	CHL_208 - Sums added to df
# 16:33:02	Start processing CHL_209.
# 16:33:22	CHL_209 - Sums added to df
# 16:33:22	Start processing CHL_210.
# 16:34:01	CHL_210 - Sums added to df
# 16:34:02	Start processing CHL_211.
# 16:35:54	CHL_211 - Sums added to df
# 16:35:54	Start processing CHL_212.
# 16:36:00	CHL_212 - Sums added to df
# 16:36:00	Start processing CHL_213.
# 16:36:05	CHL_213 - Sums added to df
# 16:36:05	Start processing CHL_214.
# 16:36:10	CHL_214 - Sums added to df
# 16:36:10	Start processing CHL_215.
# 16:36:14	CHL_215 - Sums added to df
# 16:36:14	Start processing CHL_216.
# 16:36:43	CHL_216 - Sums added to df
# 16:36:43	Start processing CHL_217.
# 16:37:06	CHL_217 - Sums added to df
# 16:37:06	Start processing CHL_218.
# 16:37:16	CHL_218 - Sums added to df
# 16:37:16	Start processing CHL_219.
# 16:37:23	CHL_219 - Sums added to df
# 16:37:23	Start processing CHL_220.
# 16:37:28	CHL_220 - Sums added to df
# 16:37:28	Start processing CHL_221.
# 16:37:35	CHL_221 - Sums added to df
# 16:37:35	Start processing CHL_222.
# 16:37:45	CHL_222 - Sums added to df
# 16:37:46	Start processing CHL_223.
# 16:37:56	CHL_223 - Sums added to df
# 16:37:56	CHL - Completed
# 16:37:56	CHN: 31
# 16:43:02	CHN: Country level fluvial merged
# 16:44:36	CHN: Country level fluvial exported
# 16:48:12	CHN: Country level pluvial merged
# 16:49:49	CHN: Country level pluvial exported
# 16:49:51	Start processing CHN_1862.
# 16:51:08	CHN_1862 - Sums added to df
# 16:51:08	Start processing CHN_1863.
# 16:51:16	CHN_1863 - Sums added to df
# 16:51:16	Start processing CHN_1864.
# 16:51:50	CHN_1864 - Sums added to df
# 16:51:51	Start processing CHN_1865.
# 16:53:14	CHN_1865 - Sums added to df
# 16:53:15	Start processing CHN_1866.
# 16:58:01	CHN_1866 - Sums added to df
# 16:58:02	Start processing CHN_1867.
# 16:59:25	CHN_1867 - Sums added to df
# 16:59:25	Start processing CHN_1868.
# 17:00:51	CHN_1868 - Sums added to df
# 17:00:51	Start processing CHN_1869.
# 17:01:56	CHN_1869 - Sums added to df
# 17:01:56	Start processing CHN_1870.
# 17:02:06	CHN_1870 - Sums added to df
# 17:02:06	Start processing CHN_1871.
# 17:03:59	CHN_1871 - Sums added to df
# 17:04:00	Start processing CHN_1872.
# 17:08:03	CHN_1872 - Sums added to df
# 17:08:04	Start processing CHN_1873.
# 17:09:25	CHN_1873 - Sums added to df
# 17:09:26	Start processing CHN_1874.
# 17:10:48	CHN_1874 - Sums added to df
# 17:10:49	Start processing CHN_1875.
# 17:12:08	CHN_1875 - Sums added to df
# 17:12:08	Start processing CHN_1876.
# 17:13:13	CHN_1876 - Sums added to df
# 17:13:14	Start processing CHN_1877.
# 17:14:28	CHN_1877 - Sums added to df
# 17:14:28	Start processing CHN_1878.
# 17:16:26	CHN_1878 - Sums added to df
# 17:16:26	Start processing CHN_1879.
# 17:17:51	CHN_1879 - Sums added to df
# 17:17:51	Start processing CHN_1880.
# 17:32:00	CHN_1880 - Sums added to df
# 17:32:03	Start processing CHN_1881.
# 17:32:37	CHN_1881 - Sums added to df
# 17:32:37	Start processing CHN_1882.
# 17:36:58	CHN_1882 - Sums added to df
# 17:36:59	Start processing CHN_1883.
# 17:39:15	CHN_1883 - Sums added to df
# 17:39:16	Start processing CHN_1884.
# 17:40:49	CHN_1884 - Sums added to df
# 17:40:49	Start processing CHN_1885.
# 17:40:55	CHN_1885 - Sums added to df
# 17:40:55	Start processing CHN_1886.
# 17:42:32	CHN_1886 - Sums added to df
# 17:42:32	Start processing CHN_1887.
# 17:46:20	CHN_1887 - Sums added to df
# 17:46:20	Start processing CHN_1888.
# 17:46:30	CHN_1888 - Sums added to df
# 17:46:30	Start processing CHN_1889.
# 17:57:27	CHN_1889 - Sums added to df
# 17:57:29	Start processing CHN_1890.
# 18:04:22	CHN_1890 - Sums added to df
# 18:04:24	Start processing CHN_1891.
# 18:07:15	CHN_1891 - Sums added to df
# 18:07:15	Start processing CHN_1892.
# 18:10:23	CHN_1892 - Sums added to df
# 18:10:24	CHN - Completed
# 18:10:24	CIV: 14
# 18:10:25	CIV: Only one fluvial tile. No merge needed
# 18:10:27	CIV: Country level fluvial exported
# 18:10:29	CIV: Only one pluvial tile. No merge needed
# 18:10:32	CIV: Country level pluvial exported
# 18:10:32	Start processing CIV_587.
# 18:10:41	CIV_587 - Sums added to df
# 18:10:41	Start processing CIV_588.
# 18:10:50	CIV_588 - Sums added to df
# 18:10:50	Start processing CIV_589.
# 18:10:51	CIV_589 - Sums added to df
# 18:10:51	Start processing CIV_590.
# 18:10:52	CIV_590 - Sums added to df
# 18:10:52	Start processing CIV_591.
# 18:10:58	CIV_591 - Sums added to df
# 18:10:58	Start processing CIV_592.
# 18:11:03	CIV_592 - Sums added to df
# 18:11:03	Start processing CIV_593.
# 18:11:10	CIV_593 - Sums added to df
# 18:11:10	Start processing CIV_594.
# 18:11:18	CIV_594 - Sums added to df
# 18:11:18	Start processing CIV_595.
# 18:11:24	CIV_595 - Sums added to df
# 18:11:24	Start processing CIV_596.
# 18:11:30	CIV_596 - Sums added to df
# 18:11:30	Start processing CIV_597.
# 18:11:37	CIV_597 - Sums added to df
# 18:11:37	Start processing CIV_598.
# 18:11:46	CIV_598 - Sums added to df
# 18:11:46	Start processing CIV_599.
# 18:11:51	CIV_599 - Sums added to df
# 18:11:51	Start processing CIV_600.
# 18:12:02	CIV_600 - Sums added to df
# 18:12:02	CIV - Completed
# 18:12:02	CMR: 10
# 18:12:05	CMR: Only one fluvial tile. No merge needed
# 18:12:10	CMR: Country level fluvial exported
# 18:12:15	CMR: Only one pluvial tile. No merge needed
# 18:12:21	CMR: Country level pluvial exported
# 18:12:22	Start processing CMR_1576.
# 18:12:38	CMR_1576 - Sums added to df
# 18:12:38	Start processing CMR_1577.
# 18:12:55	CMR_1577 - Sums added to df
# 18:12:55	Start processing CMR_1578.
# 18:13:23	CMR_1578 - Sums added to df
# 18:13:23	Start processing CMR_1579.
# 18:13:36	CMR_1579 - Sums added to df
# 18:13:36	Start processing CMR_1580.
# 18:13:43	CMR_1580 - Sums added to df
# 18:13:43	Start processing CMR_1581.
# 18:14:02	CMR_1581 - Sums added to df
# 18:14:02	Start processing CMR_1582.
# 18:14:07	CMR_1582 - Sums added to df
# 18:14:07	Start processing CMR_1583.
# 18:14:11	CMR_1583 - Sums added to df
# 18:14:11	Start processing CMR_1584.
# 18:14:22	CMR_1584 - Sums added to df
# 18:14:22	Start processing CMR_1585.
# 18:14:31	CMR_1585 - Sums added to df
# 18:14:31	CMR - Completed
# 18:14:31	COD: 11
# 18:14:40	COD: Only one fluvial tile. No merge needed
# 18:15:05	COD: Country level fluvial exported
# 18:15:18	COD: Only one pluvial tile. No merge needed
# 18:15:45	COD: Country level pluvial exported
# 18:15:45	Start processing COD_1565.
# 18:16:58	COD_1565 - Sums added to df
# 18:16:59	Start processing COD_1566.
# 18:17:13	COD_1566 - Sums added to df
# 18:17:13	Start processing COD_1567.
# 18:19:08	COD_1567 - Sums added to df
# 18:19:08	Start processing COD_1568.
# 18:19:49	COD_1568 - Sums added to df
# 18:19:50	Start processing COD_1569.
# 18:20:37	COD_1569 - Sums added to df
# 18:20:37	Start processing COD_1570.
# 18:23:10	COD_1570 - Sums added to df
# 18:23:10	Start processing COD_1571.
# 18:23:14	COD_1571 - Sums added to df
# 18:23:14	Start processing COD_1572.
# 18:23:52	COD_1572 - Sums added to df
# 18:23:52	Start processing COD_1573.
# 18:24:09	COD_1573 - Sums added to df
# 18:24:09	Start processing COD_1574.
# 18:26:03	COD_1574 - Sums added to df
# 18:26:03	Start processing COD_1575.
# 18:26:21	COD_1575 - Sums added to df
# 18:26:21	COD - Completed
# 18:26:21	COG: 12
# 18:26:23	COG: Only one fluvial tile. No merge needed
# 18:26:27	COG: Country level fluvial exported
# 18:26:30	COG: Only one pluvial tile. No merge needed
# 18:26:35	COG: Country level pluvial exported
# 18:26:35	Start processing COG_1553.
# 18:26:40	COG_1553 - Sums added to df
# 18:26:40	Start processing COG_1554.
# 18:26:40	COG_1554 - Sums added to df
# 18:26:40	Start processing COG_1555.
# 18:26:51	COG_1555 - Sums added to df
# 18:26:51	Start processing COG_1556.
# 18:26:59	COG_1556 - Sums added to df
# 18:26:59	Start processing COG_1557.
# 18:27:04	COG_1557 - Sums added to df
# 18:27:04	Start processing COG_1558.
# 18:27:10	COG_1558 - Sums added to df
# 18:27:10	Start processing COG_1559.
# 18:27:27	COG_1559 - Sums added to df
# 18:27:27	Start processing COG_1560.
# 18:27:37	COG_1560 - Sums added to df
# 18:27:37	Start processing COG_1561.
# 18:27:47	COG_1561 - Sums added to df
# 18:27:47	Start processing COG_1562.
# 18:27:48	COG_1562 - Sums added to df
# 18:27:48	Start processing COG_1563.
# 18:27:57	COG_1563 - Sums added to df
# 18:27:57	Start processing COG_1564.
# 18:28:13	COG_1564 - Sums added to df
# 18:28:14	COG - Completed
# 18:28:14	COL: 34
# 18:28:20	COL: Only one fluvial tile. No merge needed
# 18:28:35	COL: Country level fluvial exported
# 18:28:45	COL: Only one pluvial tile. No merge needed
# 18:29:03	COL: Country level pluvial exported
# 18:29:03	Start processing COL_1169.
# 18:29:05	COL_1169 - Sums added to df
# 18:29:05	Start processing COL_1210.
# 18:29:24	COL_1210 - Sums added to df
# 18:29:25	Start processing COL_1211.
# 18:29:26	COL_1211 - Sums added to df
# 18:29:26	Start processing COL_1212.
# 18:29:40	COL_1212 - Sums added to df
# 18:29:40	Start processing COL_1213.
# 18:29:51	COL_1213 - Sums added to df
# 18:29:51	Start processing COL_1214.
# 18:29:54	COL_1214 - Sums added to df
# 18:29:54	Start processing COL_1215.
# 18:30:24	COL_1215 - Sums added to df
# 18:30:24	Start processing COL_1216.
# 18:30:35	COL_1216 - Sums added to df
# 18:30:35	Start processing COL_1217.
# 18:30:43	COL_1217 - Sums added to df
# 18:30:43	Start processing COL_1218.
# 18:31:00	COL_1218 - Sums added to df
# 18:31:00	Start processing COL_1219.
# 18:31:07	COL_1219 - Sums added to df
# 18:31:07	Start processing COL_1220.
# 18:31:15	COL_1220 - Sums added to df
# 18:31:15	Start processing COL_1221.
# 18:31:24	COL_1221 - Sums added to df
# 18:31:24	Start processing COL_1222.
# 18:31:33	COL_1222 - Sums added to df
# 18:31:33	Start processing COL_1223.
# 18:31:40	COL_1223 - Sums added to df
# 18:31:40	Start processing COL_1224.
# 18:32:03	COL_1224 - Sums added to df
# 18:32:03	Start processing COL_1225.
# 18:32:13	COL_1225 - Sums added to df
# 18:32:13	Start processing COL_1226.
# 18:32:20	COL_1226 - Sums added to df
# 18:32:20	Start processing COL_1227.
# 18:32:22	COL_1227 - Sums added to df
# 18:32:22	Start processing COL_1228.
# 18:32:24	COL_1228 - Sums added to df
# 18:32:24	Start processing COL_1229.
# 18:32:33	COL_1229 - Sums added to df
# 18:32:33	Start processing COL_1230.
# 18:32:38	COL_1230 - Sums added to df
# 18:32:38	Start processing COL_1231.
# 18:32:46	COL_1231 - Sums added to df
# 18:32:46	Start processing COL_1232.
# 18:33:03	COL_1232 - Sums added to df
# 18:33:04	Start processing COL_2046.
# 18:33:39	COL_2046 - Sums added to df
# 18:33:39	Start processing COL_2047.
# 18:33:46	COL_2047 - Sums added to df
# 18:33:46	Start processing COL_2048.
# 18:33:46	COL_2048 - Sums added to df
# 18:33:46	Start processing COL_2049.
# 18:34:00	COL_2049 - Sums added to df
# 18:34:00	Start processing COL_2050.
# 18:34:20	COL_2050 - Sums added to df
# 18:34:20	Start processing COL_2051.
# 18:34:36	COL_2051 - Sums added to df
# 18:34:36	Start processing COL_2052.
# 18:34:48	COL_2052 - Sums added to df
# 18:34:48	Start processing COL_2053.
# 18:34:49	COL_2053 - Sums added to df
# 18:34:49	Start processing COL_2054.
# 18:35:07	COL_2054 - Sums added to df
# 18:35:07	Start processing COL_2055.
# 18:35:33	COL_2055 - Sums added to df
# 18:35:33	COL - Completed
# 18:35:33	COM: 3
# 18:35:33	COM: Only one fluvial tile. No merge needed
# 18:35:33	COM: Country level fluvial exported
# 18:35:33	COM: Only one pluvial tile. No merge needed
# 18:35:33	COM: Country level pluvial exported
# 18:35:33	Start processing COM_1497.
# 18:35:34	COM_1497 - Sums added to df
# 18:35:34	Start processing COM_1498.
# 18:35:34	COM_1498 - Sums added to df
# 18:35:34	Start processing COM_1499.
# 18:35:35	COM_1499 - Sums added to df
# 18:35:35	COM - Completed
# Cabo Verde does not have flood data==================================
# 18:35:35	CRI: 6
# 18:35:35	CRI: Only one fluvial tile. No merge needed
# 18:35:37	CRI: Country level fluvial exported
# 18:35:38	CRI: Only one pluvial tile. No merge needed
# 18:35:39	CRI: Country level pluvial exported
# 18:35:39	Start processing CRI_1202.
# 18:35:43	CRI_1202 - Sums added to df
# 18:35:43	Start processing CRI_1203.
# 18:35:46	CRI_1203 - Sums added to df
# 18:35:46	Start processing CRI_1204.
# 18:35:50	CRI_1204 - Sums added to df
# 18:35:50	Start processing CRI_1205.
# 18:35:54	CRI_1205 - Sums added to df
# 18:35:54	Start processing CRI_1206.
# 18:35:57	CRI_1206 - Sums added to df
# 18:35:57	Start processing CRI_1207.
# 18:36:01	CRI_1207 - Sums added to df
# 18:36:01	CRI - Completed
# 18:36:01	CUB: 1
# 18:36:02	CUB: Only one fluvial tile. No merge needed
# 18:36:04	CUB: Country level fluvial exported
# 18:36:06	CUB: Only one pluvial tile. No merge needed
# 18:36:09	CUB: Country level pluvial exported
# 18:36:09	Start processing CUB_2041.
# 18:37:08	CUB_2041 - Sums added to df
# 18:37:08	CUB - Completed
# Curacao does not have flood data==================================
# 18:37:08	CYM: 3
# 18:37:08	CYM: Only one fluvial tile. No merge needed
# 18:37:08	CYM: Country level fluvial exported
# 18:37:09	CYM: Only one pluvial tile. No merge needed
# 18:37:09	CYM: Country level pluvial exported
# 18:37:09	Start processing CYM_2101.
# 18:37:09	CYM_2101 - Sums added to df
# 18:37:09	Start processing CYM_2102.
# 18:37:09	CYM_2102 - Sums added to df
# 18:37:09	Start processing CYM_2103.
# 18:37:10	CYM_2103 - Sums added to df
# 18:37:10	CYM - Completed
# 18:37:10	CYP: 1
# 18:37:10	CYP: Only one fluvial tile. No merge needed
# 18:37:10	CYP: Country level fluvial exported
# 18:37:11	CYP: Only one pluvial tile. No merge needed
# 18:37:11	CYP: Country level pluvial exported
# 18:37:11	Start processing CYP_995.
# 18:37:16	CYP_995 - Sums added to df
# 18:37:16	CYP - Completed
# 18:37:16	CZE: 8
# 18:37:16	CZE: Only one fluvial tile. No merge needed
# 18:37:17	CZE: Country level fluvial exported
# 18:37:18	CZE: Only one pluvial tile. No merge needed
# 18:37:19	CZE: Country level pluvial exported
# 18:37:20	Start processing CZE_979.
# 18:37:20	CZE_979 - Sums added to df
# 18:37:20	Start processing CZE_980.
# 18:37:25	CZE_980 - Sums added to df
# 18:37:25	Start processing CZE_981.
# 18:37:34	CZE_981 - Sums added to df
# 18:37:34	Start processing CZE_982.
# 18:37:39	CZE_982 - Sums added to df
# 18:37:39	Start processing CZE_983.
# 18:37:45	CZE_983 - Sums added to df
# 18:37:45	Start processing CZE_984.
# 18:37:51	CZE_984 - Sums added to df
# 18:37:51	Start processing CZE_985.
# 18:37:56	CZE_985 - Sums added to df
# 18:37:56	Start processing CZE_986.
# 18:37:59	CZE_986 - Sums added to df
# 18:37:59	CZE - Completed
# 18:37:59	DEU: 16
# 18:38:01	DEU: Only one fluvial tile. No merge needed
# 18:38:06	DEU: Country level fluvial exported
# 18:38:09	DEU: Only one pluvial tile. No merge needed
# 18:38:14	DEU: Country level pluvial exported
# 18:38:15	Start processing DEU_241.
# 18:38:27	DEU_241 - Sums added to df
# 18:38:27	Start processing DEU_242.
# 18:38:41	DEU_242 - Sums added to df
# 18:38:41	Start processing DEU_243.
# 18:38:49	DEU_243 - Sums added to df
# 18:38:49	Start processing DEU_244.
# 18:38:51	DEU_244 - Sums added to df
# 18:38:51	Start processing DEU_245.
# 18:38:59	DEU_245 - Sums added to df
# 18:38:59	Start processing DEU_246.
# 18:39:09	DEU_246 - Sums added to df
# 18:39:09	Start processing DEU_247.
# 18:39:19	DEU_247 - Sums added to df
# 18:39:19	Start processing DEU_248.
# 18:39:26	DEU_248 - Sums added to df
# 18:39:26	Start processing DEU_249.
# 18:39:51	DEU_249 - Sums added to df
# 18:39:51	Start processing DEU_250.
# 18:39:52	DEU_250 - Sums added to df
# 18:39:52	Start processing DEU_251.
# 18:40:05	DEU_251 - Sums added to df
# 18:40:05	Start processing DEU_252.
# 18:40:06	DEU_252 - Sums added to df
# 18:40:06	Start processing DEU_253.
# 18:40:08	DEU_253 - Sums added to df
# 18:40:08	Start processing DEU_254.
# 18:40:18	DEU_254 - Sums added to df
# 18:40:18	Start processing DEU_255.
# 18:40:28	DEU_255 - Sums added to df
# 18:40:28	Start processing DEU_256.
# 18:40:50	DEU_256 - Sums added to df
# 18:40:50	DEU - Completed
# 18:40:50	DJI: 6
# 18:40:50	DJI: Only one fluvial tile. No merge needed
# 18:40:50	DJI: Country level fluvial exported
# 18:40:51	DJI: Only one pluvial tile. No merge needed
# 18:40:51	DJI: Country level pluvial exported
# 18:40:51	Start processing DJI_1825.
# 18:40:53	DJI_1825 - Sums added to df
# 18:40:53	Start processing DJI_1826.
# 18:40:54	DJI_1826 - Sums added to df
# 18:40:54	Start processing DJI_1827.
# 18:40:56	DJI_1827 - Sums added to df
# 18:40:56	Start processing DJI_1828.
# 18:40:57	DJI_1828 - Sums added to df
# 18:40:57	Start processing DJI_1829.
# 18:40:57	DJI_1829 - Sums added to df
# 18:40:57	Start processing DJI_1830.
# 18:40:59	DJI_1830 - Sums added to df
# 18:40:59	DJI - Completed
# 18:40:59	DMA: 10
# 18:40:59	DMA: Only one fluvial tile. No merge needed
# 18:40:59	DMA: Country level fluvial exported
# 18:40:59	DMA: Only one pluvial tile. No merge needed
# 18:40:59	DMA: Country level pluvial exported
# 18:40:59	Start processing DMA_2086.
# 18:41:00	DMA_2086 - Sums added to df
# 18:41:00	Start processing DMA_2087.
# 18:41:00	DMA_2087 - Sums added to df
# 18:41:00	Start processing DMA_2088.
# 18:41:00	DMA_2088 - Sums added to df
# 18:41:00	Start processing DMA_2089.
# 18:41:01	DMA_2089 - Sums added to df
# 18:41:01	Start processing DMA_2090.
# 18:41:01	DMA_2090 - Sums added to df
# 18:41:01	Start processing DMA_2091.
# 18:41:01	DMA_2091 - Sums added to df
# 18:41:01	Start processing DMA_2092.
# 18:41:02	DMA_2092 - Sums added to df
# 18:41:02	Start processing DMA_2093.
# 18:41:02	DMA_2093 - Sums added to df
# 18:41:02	Start processing DMA_2094.
# 18:41:03	DMA_2094 - Sums added to df
# 18:41:03	Start processing DMA_2095.
# 18:41:03	DMA_2095 - Sums added to df
# 18:41:03	DMA - Completed
# 18:41:03	DNK: 11
# 18:41:04	DNK: Only one fluvial tile. No merge needed
# 18:41:05	DNK: Country level fluvial exported
# 18:41:06	DNK: Only one pluvial tile. No merge needed
# 18:41:07	DNK: Country level pluvial exported
# 18:41:07	Start processing DNK_257.
# 18:41:08	DNK_257 - Sums added to df
# 18:41:08	Start processing DNK_258.
# 18:41:12	DNK_258 - Sums added to df
# 18:41:13	Start processing DNK_259.
# 18:41:14	DNK_259 - Sums added to df
# 18:41:14	Start processing DNK_260.
# 18:41:14	DNK_260 - Sums added to df
# 18:41:14	Start processing DNK_261.
# 18:41:20	DNK_261 - Sums added to df
# 18:41:20	Start processing DNK_262.
# 18:41:21	DNK_262 - Sums added to df
# 18:41:21	Start processing DNK_263.
# 18:41:22	DNK_263 - Sums added to df
# 18:41:22	Start processing DNK_264.
# 18:41:25	DNK_264 - Sums added to df
# 18:41:25	Start processing DNK_265.
# 18:41:28	DNK_265 - Sums added to df
# 18:41:28	Start processing DNK_266.
# 18:41:32	DNK_266 - Sums added to df
# 18:41:32	Start processing DNK_267.
# 18:41:37	DNK_267 - Sums added to df
# 18:41:37	DNK - Completed
# 18:41:37	DOM: 10
# 18:41:37	DOM: Only one fluvial tile. No merge needed
# 18:41:38	DOM: Country level fluvial exported
# 18:41:38	DOM: Only one pluvial tile. No merge needed
# 18:41:39	DOM: Country level pluvial exported
# 18:41:39	Start processing DOM_1400.
# 18:41:41	DOM_1400 - Sums added to df
# 18:41:41	Start processing DOM_1401.
# 18:41:44	DOM_1401 - Sums added to df
# 18:41:44	Start processing DOM_1402.
# 18:41:46	DOM_1402 - Sums added to df
# 18:41:46	Start processing DOM_1403.
# 18:41:48	DOM_1403 - Sums added to df
# 18:41:48	Start processing DOM_1404.
# 18:41:50	DOM_1404 - Sums added to df
# 18:41:50	Start processing DOM_1405.
# 18:41:52	DOM_1405 - Sums added to df
# 18:41:52	Start processing DOM_1406.
# 18:41:54	DOM_1406 - Sums added to df
# 18:41:54	Start processing DOM_1407.
# 18:41:55	DOM_1407 - Sums added to df
# 18:41:55	Start processing DOM_1408.
# 18:41:57	DOM_1408 - Sums added to df
# 18:41:57	Start processing DOM_1409.
# 18:42:00	DOM_1409 - Sums added to df
# 18:42:00	DOM - Completed
# 18:42:00	DZA: 1
# 18:42:07	DZA: Only one fluvial tile. No merge needed
# 18:42:25	DZA: Country level fluvial exported
# 18:42:35	DZA: Only one pluvial tile. No merge needed
# 18:42:53	DZA: Country level pluvial exported
# 18:42:53	Start processing DZA_754.
# 18:54:50	DZA_754 - Sums added to df
# 18:54:53	DZA - Completed
# 18:54:53	ECU: 25
# 18:54:55	ECU: Only one fluvial tile. No merge needed
# 18:55:02	ECU: Country level fluvial exported
# 18:55:06	ECU: Only one pluvial tile. No merge needed
# 18:55:14	ECU: Country level pluvial exported
# 18:55:16	Start processing ECU_1264.
# 18:55:20	ECU_1264 - Sums added to df
# 18:55:20	Start processing ECU_1265.
# 18:55:22	ECU_1265 - Sums added to df
# 18:55:22	Start processing ECU_1266.
# 18:55:23	ECU_1266 - Sums added to df
# 18:55:23	Start processing ECU_1267.
# 18:55:25	ECU_1267 - Sums added to df
# 18:55:25	Start processing ECU_1268.
# 18:55:28	ECU_1268 - Sums added to df
# 18:55:28	Start processing ECU_1269.
# 18:55:31	ECU_1269 - Sums added to df
# 18:55:31	Start processing ECU_1270.
# 18:55:33	ECU_1270 - Sums added to df
# 18:55:33	Start processing ECU_1271.
# 18:55:39	ECU_1271 - Sums added to df
# 18:55:39	Start processing ECU_1272.
# 18:55:41	ECU_1272 - Sums added to df
# 18:55:41	Start processing ECU_1273.
# 18:55:46	ECU_1273 - Sums added to df
# 18:55:46	Start processing ECU_1274.
# 18:55:50	ECU_1274 - Sums added to df
# 18:55:50	Start processing ECU_1275.
# 18:55:58	ECU_1275 - Sums added to df
# 18:55:58	Start processing ECU_1276.
# 18:56:07	ECU_1276 - Sums added to df
# 18:56:07	Start processing ECU_1277.
# 18:56:12	ECU_1277 - Sums added to df
# 18:56:12	Start processing ECU_1278.
# 18:56:20	ECU_1278 - Sums added to df
# 18:56:20	Start processing ECU_1279.
# 18:56:29	ECU_1279 - Sums added to df
# 18:56:29	Start processing ECU_1280.
# 18:56:35	ECU_1280 - Sums added to df
# 18:56:36	Start processing ECU_1281.
# 18:56:37	ECU_1281 - Sums added to df
# 18:56:37	Start processing ECU_1282.
# 18:56:41	ECU_1282 - Sums added to df
# 18:56:41	Start processing ECU_1283.
# 18:56:46	ECU_1283 - Sums added to df
# 18:56:46	Start processing ECU_1284.
# 18:56:54	ECU_1284 - Sums added to df
# 18:56:54	Start processing ECU_1285.
# 18:56:58	ECU_1285 - Sums added to df
# 18:56:58	Start processing ECU_1286.
# 18:57:00	ECU_1286 - Sums added to df
# 18:57:00	Start processing ECU_1287.
# 18:57:02	ECU_1287 - Sums added to df
# 18:57:02	Start processing ECU_2056.
# 18:57:16	ECU_2056 - Sums added to df
# 18:57:16	ECU - Completed
# 18:57:16	EGY: 4
# 18:57:19	EGY: Only one fluvial tile. No merge needed
# 18:57:25	EGY: Country level fluvial exported
# 18:57:29	EGY: Only one pluvial tile. No merge needed
# 18:57:35	EGY: Country level pluvial exported
# 18:57:36	Start processing EGY_1821.
# 19:00:30	EGY_1821 - Sums added to df
# 19:00:31	Start processing EGY_1822.
# 19:00:41	EGY_1822 - Sums added to df
# 19:00:41	Start processing EGY_1823.
# 19:00:55	EGY_1823 - Sums added to df
# 19:00:55	Start processing EGY_1824.
# 19:02:07	EGY_1824 - Sums added to df
# 19:02:07	EGY - Completed
# 19:02:07	ERI: 7
# 19:02:08	ERI: Only one fluvial tile. No merge needed
# 19:02:10	ERI: Country level fluvial exported
# 19:02:12	ERI: Only one pluvial tile. No merge needed
# 19:02:14	ERI: Country level pluvial exported
# 19:02:14	Start processing ERI_2140.
# 19:02:22	ERI_2140 - Sums added to df
# 19:02:22	Start processing ERI_2141.
# 19:02:25	ERI_2141 - Sums added to df
# 19:02:25	Start processing ERI_2142.
# 19:02:28	ERI_2142 - Sums added to df
# 19:02:28	Start processing ERI_2143.
# 19:02:39	ERI_2143 - Sums added to df
# 19:02:39	Start processing ERI_2144.
# 19:02:48	ERI_2144 - Sums added to df
# 19:02:48	Start processing ERI_2145.
# 19:02:49	ERI_2145 - Sums added to df
# 19:02:49	Start processing ERI_2146.
# 19:03:05	ERI_2146 - Sums added to df
# 19:03:05	ERI - Completed
# 19:03:05	ESP: 19
# 19:03:15	ESP: Only one fluvial tile. No merge needed
# 19:03:33	ESP: Country level fluvial exported
# 19:03:43	ESP: Only one pluvial tile. No merge needed
# 19:04:02	ESP: Country level pluvial exported
# 19:04:03	Start processing ESP_951.
# 19:04:15	ESP_951 - Sums added to df
# 19:04:15	Start processing ESP_952.
# 19:04:42	ESP_952 - Sums added to df
# 19:04:43	Start processing ESP_953.
# 19:04:46	ESP_953 - Sums added to df
# 19:04:46	Start processing ESP_954.
# 19:05:14	ESP_954 - Sums added to df
# 19:05:14	Start processing ESP_955.
# 19:05:43	ESP_955 - Sums added to df
# 19:05:43	Start processing ESP_956.
# 19:05:44	ESP_956 - Sums added to df
# 19:05:44	Start processing ESP_957.
# 19:05:44	ESP_957 - Sums added to df
# 19:05:44	Start processing ESP_958.
# 19:05:49	ESP_958 - Sums added to df
# 19:05:49	Start processing ESP_959.
# 19:05:55	ESP_959 - Sums added to df
# 19:05:55	Start processing ESP_960.
# 19:06:09	ESP_960 - Sums added to df
# 19:06:09	Start processing ESP_961.
# 19:06:19	ESP_961 - Sums added to df
# 19:06:19	Start processing ESP_962.
# 19:06:21	ESP_962 - Sums added to df
# 19:06:21	Start processing ESP_963.
# 19:06:25	ESP_963 - Sums added to df
# 19:06:25	Start processing ESP_964.
# 19:06:29	ESP_964 - Sums added to df
# 19:06:29	Start processing ESP_965.
# 19:06:34	ESP_965 - Sums added to df
# 19:06:34	Start processing ESP_966.
# 19:06:51	ESP_966 - Sums added to df
# 19:06:51	Start processing ESP_967.
# 19:07:02	ESP_967 - Sums added to df
# 19:07:02	Start processing ESP_968.
# 19:07:16	ESP_968 - Sums added to df
# 19:07:16	Start processing ESP_969.
# 19:07:23	ESP_969 - Sums added to df
# 19:07:23	ESP - Completed
# 19:07:23	EST: 16
# 19:07:23	EST: Only one fluvial tile. No merge needed
# 19:07:24	EST: Country level fluvial exported
# 19:07:25	EST: Only one pluvial tile. No merge needed
# 19:07:26	EST: Country level pluvial exported
# 19:07:26	Start processing EST_268.
# 19:07:27	EST_268 - Sums added to df
# 19:07:27	Start processing EST_269.
# 19:07:30	EST_269 - Sums added to df
# 19:07:30	Start processing EST_270.
# 19:07:31	EST_270 - Sums added to df
# 19:07:31	Start processing EST_271.
# 19:07:33	EST_271 - Sums added to df
# 19:07:33	Start processing EST_272.
# 19:07:35	EST_272 - Sums added to df
# 19:07:35	Start processing EST_273.
# 19:07:37	EST_273 - Sums added to df
# 19:07:37	Start processing EST_274.
# 19:07:39	EST_274 - Sums added to df
# 19:07:39	Start processing EST_275.
# 19:07:41	EST_275 - Sums added to df
# 19:07:41	Start processing EST_276.
# 19:07:42	EST_276 - Sums added to df
# 19:07:42	Start processing EST_277.
# 19:07:45	EST_277 - Sums added to df
# 19:07:45	Start processing EST_278.
# 19:07:47	EST_278 - Sums added to df
# 19:07:47	Start processing EST_279.
# 19:07:50	EST_279 - Sums added to df
# 19:07:50	Start processing EST_280.
# 19:07:52	EST_280 - Sums added to df
# 19:07:52	Start processing EST_281.
# 19:07:54	EST_281 - Sums added to df
# 19:07:54	Start processing EST_282.
# 19:07:56	EST_282 - Sums added to df
# 19:07:56	Start processing EST_283.
# 19:07:57	EST_283 - Sums added to df
# 19:07:57	EST - Completed
# 19:07:57	ETH: 11
# 19:08:01	ETH: Only one fluvial tile. No merge needed
# 19:08:11	ETH: Country level fluvial exported
# 19:08:17	ETH: Only one pluvial tile. No merge needed
# 19:08:29	ETH: Country level pluvial exported
# 19:08:29	Start processing ETH_1500.
# 19:08:30	ETH_1500 - Sums added to df
# 19:08:30	Start processing ETH_1501.
# 19:08:58	ETH_1501 - Sums added to df
# 19:08:58	Start processing ETH_1502.
# 19:09:40	ETH_1502 - Sums added to df
# 19:09:40	Start processing ETH_1503.
# 19:09:55	ETH_1503 - Sums added to df
# 19:09:55	Start processing ETH_1504.
# 19:09:56	ETH_1504 - Sums added to df
# 19:09:56	Start processing ETH_1505.
# 19:10:07	ETH_1505 - Sums added to df
# 19:10:08	Start processing ETH_1506.
# 19:10:08	ETH_1506 - Sums added to df
# 19:10:08	Start processing ETH_1507.
# 19:11:43	ETH_1507 - Sums added to df
# 19:11:44	Start processing ETH_1508.
# 19:12:13	ETH_1508 - Sums added to df
# 19:12:13	Start processing ETH_1509.
# 19:13:56	ETH_1509 - Sums added to df
# 19:13:56	Start processing ETH_1510.
# 19:14:12	ETH_1510 - Sums added to df
# 19:14:12	ETH - Completed
# 19:14:12	FIN: 5
# 19:14:16	FIN: Only one fluvial tile. No merge needed
# 19:14:23	FIN: Country level fluvial exported
# 19:14:28	FIN: Only one pluvial tile. No merge needed
# 19:14:36	FIN: Country level pluvial exported
# 19:14:37	Start processing FIN_975.
# 19:17:25	FIN_975 - Sums added to df
# 19:17:26	Start processing FIN_976.
# 19:17:56	FIN_976 - Sums added to df
# 19:17:56	Start processing FIN_977.
# 19:18:25	FIN_977 - Sums added to df
# 19:18:25	Start processing FIN_978.
# 19:18:32	FIN_978 - Sums added to df
# 19:18:32	Start processing FIN_1950.
# 19:18:34	FIN_1950 - Sums added to df
# 19:18:34	FIN - Completed
# 19:18:34	FJI: 4
# 19:18:36	FJI: Only one fluvial tile. No merge needed
# 19:18:40	FJI: Country level fluvial exported
# 19:18:52	FJI: Country level pluvial merged
# 19:21:09	FJI: Country level pluvial exported
# 19:21:11	Start processing FJI_1136.
# 19:21:52	FJI_1136 - Sums added to df
# 19:21:52	Start processing FJI_1137.
# 19:29:57	FJI_1137 - adm1 memory error
# 19:30:00	Start processing FJI_1138.
# 19:39:13	FJI_1138 - adm1 memory error
# 19:39:17	Start processing FJI_1139.
# 19:40:32	FJI_1139 - Sums added to df
# 19:40:32	FJI - Completed
# 19:40:32	FRA: 22
# 19:40:35	FRA: Only one fluvial tile. No merge needed
# 19:40:42	FRA: Country level fluvial exported
# 19:40:47	FRA: Only one pluvial tile. No merge needed
# 19:40:55	FRA: Country level pluvial exported
# 19:40:56	Start processing FRA_284.
# 19:41:00	FRA_284 - Sums added to df
# 19:41:00	Start processing FRA_285.
# 19:41:05	FRA_285 - Sums added to df
# 19:41:05	Start processing FRA_286.
# 19:41:11	FRA_286 - Sums added to df
# 19:41:11	Start processing FRA_287.
# 19:41:24	FRA_287 - Sums added to df
# 19:41:24	Start processing FRA_288.
# 19:41:34	FRA_288 - Sums added to df
# 19:41:34	Start processing FRA_289.
# 19:41:43	FRA_289 - Sums added to df
# 19:41:43	Start processing FRA_290.
# 19:41:58	FRA_290 - Sums added to df
# 19:41:58	Start processing FRA_291.
# 19:42:12	FRA_291 - Sums added to df
# 19:42:12	Start processing FRA_292.
# 19:42:18	FRA_292 - Sums added to df
# 19:42:18	Start processing FRA_293.
# 19:42:31	FRA_293 - Sums added to df
# 19:42:31	Start processing FRA_294.
# 19:42:40	FRA_294 - Sums added to df
# 19:42:40	Start processing FRA_295.
# 19:42:51	FRA_295 - Sums added to df
# 19:42:51	Start processing FRA_296.
# 19:43:04	FRA_296 - Sums added to df
# 19:43:04	Start processing FRA_297.
# 19:43:15	FRA_297 - Sums added to df
# 19:43:15	Start processing FRA_298.
# 19:43:18	FRA_298 - Sums added to df
# 19:43:18	Start processing FRA_299.
# 19:43:25	FRA_299 - Sums added to df
# 19:43:25	Start processing FRA_300.
# 19:43:30	FRA_300 - Sums added to df
# 19:43:30	Start processing FRA_301.
# 19:43:43	FRA_301 - Sums added to df
# 19:43:43	Start processing FRA_302.
# 19:43:51	FRA_302 - Sums added to df
# 19:43:51	Start processing FRA_303.
# 19:44:01	FRA_303 - Sums added to df
# 19:44:01	Start processing FRA_304.
# 19:44:06	FRA_304 - Sums added to df
# 19:44:06	Start processing FRA_305.
# 19:44:14	FRA_305 - Sums added to df
# 19:44:14	FRA - Completed
# 19:44:14	FRO: 1
# 19:44:14	FRO: Only one fluvial tile. No merge needed
# 19:44:14	FRO: Country level fluvial exported
# 19:44:14	FRO: Only one pluvial tile. No merge needed
# 19:44:14	FRO: Country level pluvial exported
# 19:44:14	Start processing FRO_1905.
# 19:44:17	FRO_1905 - Sums added to df
# 19:44:17	FRO - Completed
# 19:44:17	FSM: 4
# 19:44:19	FSM: Only one fluvial tile. No merge needed
# 19:44:27	FSM: Country level fluvial exported
# 19:44:31	FSM: Only one pluvial tile. No merge needed
# 19:44:38	FSM: Country level pluvial exported
# 19:44:38	Start processing FSM_0.
# 19:45:16	FSM_0 - Sums added to df
# 19:45:17	Start processing FSM_1.
# 19:45:38	FSM_1 - Sums added to df
# 19:45:38	Start processing FSM_2.
# 19:45:55	FSM_2 - adm1 value error
# 19:45:55	Start processing FSM_3.
# 19:45:55	FSM_3 - Sums added to df
# 19:45:55	FSM - Completed
# 19:45:55	GAB: 7
# 19:45:56	GAB: Only one fluvial tile. No merge needed
# 19:45:58	GAB: Country level fluvial exported
# 19:45:59	GAB: Only one pluvial tile. No merge needed
# 19:46:02	GAB: Country level pluvial exported
# 19:46:02	Start processing GAB_601.
# 19:46:02	GAB_601 - Sums added to df
# 19:46:02	Start processing GAB_602.
# 19:46:18	GAB_602 - Sums added to df
# 19:46:18	Start processing GAB_603.
# 19:46:21	GAB_603 - Sums added to df
# 19:46:21	Start processing GAB_604.
# 19:46:23	GAB_604 - Sums added to df
# 19:46:23	Start processing GAB_605.
# 19:46:41	GAB_605 - Sums added to df
# 19:46:41	Start processing GAB_606.
# 19:46:55	GAB_606 - Sums added to df
# 19:46:55	Start processing GAB_607.
# 19:47:08	GAB_607 - Sums added to df
# 19:47:08	GAB - Completed
# 19:47:08	GBR: 12
# 19:47:12	GBR: Only one fluvial tile. No merge needed
# 19:47:20	GBR: Country level fluvial exported
# 19:47:24	GBR: Only one pluvial tile. No merge needed
# 19:47:32	GBR: Country level pluvial exported
# 19:47:33	Start processing GBR_934.
# 19:47:37	GBR_934 - Sums added to df
# 19:47:37	Start processing GBR_935.
# 19:47:43	GBR_935 - Sums added to df
# 19:47:43	Start processing GBR_936.
# 19:47:49	GBR_936 - Sums added to df
# 19:47:49	Start processing GBR_937.
# 19:47:55	GBR_937 - Sums added to df
# 19:47:55	Start processing GBR_938.
# 19:48:00	GBR_938 - Sums added to df
# 19:48:00	Start processing GBR_939.
# 19:48:07	GBR_939 - Sums added to df
# 19:48:07	Start processing GBR_940.
# 19:48:08	GBR_940 - Sums added to df
# 19:48:08	Start processing GBR_941.
# 19:48:16	GBR_941 - Sums added to df
# 19:48:16	Start processing GBR_942.
# 19:48:30	GBR_942 - Sums added to df
# 19:48:30	Start processing GBR_943.
# 19:48:38	GBR_943 - Sums added to df
# 19:48:38	Start processing GBR_944.
# 19:49:40	GBR_944 - Sums added to df
# 19:49:41	Start processing GBR_945.
# 19:49:46	GBR_945 - Sums added to df
# 19:49:46	GBR - Completed
# 19:49:46	GEO: 11
# 19:49:47	GEO: Only one fluvial tile. No merge needed
# 19:49:48	GEO: Country level fluvial exported
# 19:49:48	GEO: Only one pluvial tile. No merge needed
# 19:49:50	GEO: Country level pluvial exported
# 19:49:50	Start processing GEO_848.
# 19:49:53	GEO_848 - Sums added to df
# 19:49:53	Start processing GEO_849.
# 19:49:54	GEO_849 - Sums added to df
# 19:49:54	Start processing GEO_850.
# 19:49:55	GEO_850 - Sums added to df
# 19:49:55	Start processing GEO_851.
# 19:50:00	GEO_851 - Sums added to df
# 19:50:00	Start processing GEO_852.
# 19:50:02	GEO_852 - Sums added to df
# 19:50:02	Start processing GEO_853.
# 19:50:04	GEO_853 - Sums added to df
# 19:50:04	Start processing GEO_854.
# 19:50:07	GEO_854 - Sums added to df
# 19:50:07	Start processing GEO_855.
# 19:50:09	GEO_855 - Sums added to df
# 19:50:09	Start processing GEO_856.
# 19:50:11	GEO_856 - Sums added to df
# 19:50:11	Start processing GEO_857.
# 19:50:12	GEO_857 - Sums added to df
# 19:50:12	Start processing GEO_1949.
# 19:50:15	GEO_1949 - Sums added to df
# 19:50:15	GEO - Completed
# 19:50:15	GHA: 10
# 19:50:16	GHA: Only one fluvial tile. No merge needed
# 19:50:18	GHA: Country level fluvial exported
# 19:50:19	GHA: Only one pluvial tile. No merge needed
# 19:50:21	GHA: Country level pluvial exported
# 19:50:21	Start processing GHA_1655.
# 19:50:28	GHA_1655 - Sums added to df
# 19:50:28	Start processing GHA_1656.
# 19:50:41	GHA_1656 - Sums added to df
# 19:50:41	Start processing GHA_1657.
# 19:50:45	GHA_1657 - Sums added to df
# 19:50:45	Start processing GHA_1658.
# 19:50:49	GHA_1658 - Sums added to df
# 19:50:49	Start processing GHA_1659.
# 19:50:50	GHA_1659 - Sums added to df
# 19:50:50	Start processing GHA_1660.
# 19:51:05	GHA_1660 - Sums added to df
# 19:51:05	Start processing GHA_1661.
# 19:51:08	GHA_1661 - Sums added to df
# 19:51:08	Start processing GHA_1662.
# 19:51:12	GHA_1662 - Sums added to df
# 19:51:12	Start processing GHA_1663.
# 19:51:19	GHA_1663 - Sums added to df
# 19:51:20	Start processing GHA_1664.
# 19:51:26	GHA_1664 - Sums added to df
# 19:51:26	GHA - Completed
# 19:51:26	GIN: 8
# 19:51:27	GIN: Only one fluvial tile. No merge needed
# 19:51:29	GIN: Country level fluvial exported
# 19:51:31	GIN: Only one pluvial tile. No merge needed
# 19:51:33	GIN: Country level pluvial exported
# 19:51:34	Start processing GIN_1780.
# 19:51:46	GIN_1780 - Sums added to df
# 19:51:46	Start processing GIN_1781.
# 19:51:47	GIN_1781 - Sums added to df
# 19:51:47	Start processing GIN_1782.
# 19:51:58	GIN_1782 - Sums added to df
# 19:51:58	Start processing GIN_1783.
# 19:52:14	GIN_1783 - Sums added to df
# 19:52:14	Start processing GIN_1784.
# 19:52:21	GIN_1784 - Sums added to df
# 19:52:21	Start processing GIN_1785.
# 19:52:26	GIN_1785 - Sums added to df
# 19:52:26	Start processing GIN_1786.
# 19:52:36	GIN_1786 - Sums added to df
# 19:52:36	Start processing GIN_1787.
# 19:52:41	GIN_1787 - Sums added to df
# 19:52:41	GIN - Completed
# 19:52:41	GMB: 8
# 19:52:41	GMB: Only one fluvial tile. No merge needed
# 19:52:42	GMB: Country level fluvial exported
# 19:52:42	GMB: Only one pluvial tile. No merge needed
# 19:52:42	GMB: Country level pluvial exported
# 19:52:42	Start processing GMB_631.
# 19:52:42	GMB_631 - Sums added to df
# 19:52:42	Start processing GMB_632.
# 19:52:43	GMB_632 - Sums added to df
# 19:52:43	Start processing GMB_633.
# 19:52:44	GMB_633 - Sums added to df
# 19:52:44	Start processing GMB_634.
# 19:52:44	GMB_634 - Sums added to df
# 19:52:44	Start processing GMB_635.
# 19:52:45	GMB_635 - Sums added to df
# 19:52:45	Start processing GMB_636.
# 19:52:46	GMB_636 - Sums added to df
# 19:52:46	Start processing GMB_637.
# 19:52:47	GMB_637 - Sums added to df
# 19:52:47	Start processing GMB_638.
# 19:52:48	GMB_638 - Sums added to df
# 19:52:48	GMB - Completed
# 19:52:48	GNB: 9
# 19:52:48	GNB: Only one fluvial tile. No merge needed
# 19:52:49	GNB: Country level fluvial exported
# 19:52:49	GNB: Only one pluvial tile. No merge needed
# 19:52:49	GNB: Country level pluvial exported
# 19:52:49	Start processing GNB_1715.
# 19:52:51	GNB_1715 - Sums added to df
# 19:52:51	Start processing GNB_1716.
# 19:52:52	GNB_1716 - Sums added to df
# 19:52:52	Start processing GNB_1717.
# 19:52:54	GNB_1717 - Sums added to df
# 19:52:54	Start processing GNB_1718.
# 19:52:57	GNB_1718 - Sums added to df
# 19:52:57	Start processing GNB_1719.
# 19:52:59	GNB_1719 - Sums added to df
# 19:52:59	Start processing GNB_1720.
# 19:53:01	GNB_1720 - Sums added to df
# 19:53:01	Start processing GNB_1721.
# 19:53:03	GNB_1721 - Sums added to df
# 19:53:03	Start processing GNB_1722.
# 19:53:03	GNB_1722 - Sums added to df
# 19:53:03	Start processing GNB_1723.
# 19:53:05	GNB_1723 - Sums added to df
# 19:53:06	GNB - Completed
# 19:53:06	GNQ: 7
# 19:53:06	GNQ: Only one fluvial tile. No merge needed
# 19:53:08	GNQ: Country level fluvial exported
# 19:53:09	GNQ: Only one pluvial tile. No merge needed
# 19:53:10	GNQ: Country level pluvial exported
# 19:53:10	Start processing GNQ_2165.
# 19:53:11	GNQ_2165 - Sums added to df
# 19:53:11	Start processing GNQ_2166.
# 19:53:11	GNQ_2166 - Sums added to df
# 19:53:11	Start processing GNQ_2167.
# 19:53:12	GNQ_2167 - Sums added to df
# 19:53:12	Start processing GNQ_2168.
# 19:53:14	GNQ_2168 - Sums added to df
# 19:53:14	Start processing GNQ_2169.
# 19:53:15	GNQ_2169 - Sums added to df
# 19:53:15	Start processing GNQ_2170.
# 19:53:18	GNQ_2170 - Sums added to df
# 19:53:18	Start processing GNQ_2171.
# 19:53:19	GNQ_2171 - Sums added to df
# 19:53:19	GNQ - Completed
# 19:53:19	GRC: 4
# 19:53:21	GRC: Only one fluvial tile. No merge needed
# 19:53:25	GRC: Country level fluvial exported
# 19:53:27	GRC: Only one pluvial tile. No merge needed
# 19:53:31	GRC: Country level pluvial exported
# 19:53:32	Start processing GRC_877.
# 19:53:36	GRC_877 - Sums added to df
# 19:53:36	Start processing GRC_878.
# 19:54:14	GRC_878 - Sums added to df
# 19:54:15	Start processing GRC_879.
# 19:54:39	GRC_879 - Sums added to df
# 19:54:40	Start processing GRC_880.
# 19:55:06	GRC_880 - Sums added to df
# 19:55:06	GRC - Completed
# 19:55:06	GRD: 7
# 19:55:06	GRD: Only one fluvial tile. No merge needed
# 19:55:06	GRD: Country level fluvial exported
# 19:55:06	GRD: Only one pluvial tile. No merge needed
# 19:55:06	GRD: Country level pluvial exported
# 19:55:06	Start processing GRD_2061.
# 19:55:06	GRD_2061 - Sums added to df
# 19:55:06	Start processing GRD_2062.
# 19:55:07	GRD_2062 - Sums added to df
# 19:55:07	Start processing GRD_2063.
# 19:55:07	GRD_2063 - Sums added to df
# 19:55:07	Start processing GRD_2064.
# 19:55:07	GRD_2064 - Sums added to df
# 19:55:07	Start processing GRD_2065.
# 19:55:08	GRD_2065 - Sums added to df
# 19:55:08	Start processing GRD_2113.
# 19:55:08	GRD_2113 - Sums added to df
# 19:55:08	Start processing GRD_2114.
# 19:55:09	GRD_2114 - Sums added to df
# 19:55:09	GRD - Completed
# Greenland does not have flood data==================================
# 19:55:09	GTM: 22
# 19:55:09	GTM: Only one fluvial tile. No merge needed
# 19:55:10	GTM: Country level fluvial exported
# 19:55:11	GTM: Only one pluvial tile. No merge needed
# 19:55:12	GTM: Country level pluvial exported
# 19:55:12	Start processing GTM_1324.
# 19:55:13	GTM_1324 - Sums added to df
# 19:55:13	Start processing GTM_1325.
# 19:55:14	GTM_1325 - Sums added to df
# 19:55:14	Start processing GTM_1326.
# 19:55:14	GTM_1326 - Sums added to df
# 19:55:14	Start processing GTM_1327.
# 19:55:15	GTM_1327 - Sums added to df
# 19:55:15	Start processing GTM_1328.
# 19:55:16	GTM_1328 - Sums added to df
# 19:55:16	Start processing GTM_1329.
# 19:55:17	GTM_1329 - Sums added to df
# 19:55:17	Start processing GTM_1330.
# 19:55:18	GTM_1330 - Sums added to df
# 19:55:18	Start processing GTM_1331.
# 19:55:19	GTM_1331 - Sums added to df
# 19:55:19	Start processing GTM_1332.
# 19:55:20	GTM_1332 - Sums added to df
# 19:55:20	Start processing GTM_1333.
# 19:55:21	GTM_1333 - Sums added to df
# 19:55:21	Start processing GTM_1334.
# 19:55:22	GTM_1334 - Sums added to df
# 19:55:22	Start processing GTM_1335.
# 19:55:24	GTM_1335 - Sums added to df
# 19:55:24	Start processing GTM_1336.
# 19:55:25	GTM_1336 - Sums added to df
# 19:55:25	Start processing GTM_1337.
# 19:55:28	GTM_1337 - Sums added to df
# 19:55:28	Start processing GTM_1338.
# 19:55:29	GTM_1338 - Sums added to df
# 19:55:29	Start processing GTM_1339.
# 19:55:32	GTM_1339 - Sums added to df
# 19:55:32	Start processing GTM_1340.
# 19:55:39	GTM_1340 - Sums added to df
# 19:55:39	Start processing GTM_1341.
# 19:55:41	GTM_1341 - Sums added to df
# 19:55:41	Start processing GTM_1342.
# 19:55:42	GTM_1342 - Sums added to df
# 19:55:42	Start processing GTM_1343.
# 19:55:43	GTM_1343 - Sums added to df
# 19:55:43	Start processing GTM_1344.
# 19:55:44	GTM_1344 - Sums added to df
# 19:55:44	Start processing GTM_1345.
# 19:55:45	GTM_1345 - Sums added to df
# 19:55:45	GTM - Completed
# 19:55:45	GUM: 1
# 19:55:45	GUM: Only one fluvial tile. No merge needed
# 19:55:45	GUM: Country level fluvial exported
# 19:55:45	GUM: Only one pluvial tile. No merge needed
# 19:55:45	GUM: Country level pluvial exported
# 19:55:45	Start processing GUM_2036.
# 19:55:46	GUM_2036 - Sums added to df
# 19:55:46	GUM - Completed
# 19:55:46	GUY: 1
# 19:55:47	GUY: Only one fluvial tile. No merge needed
# 19:55:49	GUY: Country level fluvial exported
# 19:55:50	GUY: Only one pluvial tile. No merge needed
# 19:55:53	GUY: Country level pluvial exported
# 19:55:53	Start processing GUY_1208.
# 19:56:45	GUY_1208 - Sums added to df
# 19:56:45	GUY - Completed
# 19:56:45	HKG: 1
# 19:56:45	HKG: Only one fluvial tile. No merge needed
# 19:56:45	HKG: Country level fluvial exported
# 19:56:45	HKG: Only one pluvial tile. No merge needed
# 19:56:45	HKG: Country level pluvial exported
# 19:56:45	Start processing HKG_2019.
# 19:56:46	HKG_2019 - Sums added to df
# 19:56:46	HKG - Completed
# 19:56:46	HND: 19
# 19:56:47	HND: Only one fluvial tile. No merge needed
# 19:56:48	HND: Country level fluvial exported
# 19:56:49	HND: Only one pluvial tile. No merge needed
# 19:56:51	HND: Country level pluvial exported
# 19:56:51	Start processing HND_1410.
# 19:56:52	HND_1410 - Sums added to df
# 19:56:52	Start processing HND_1411.
# 19:56:54	HND_1411 - Sums added to df
# 19:56:54	Start processing HND_1412.
# 19:56:57	HND_1412 - Sums added to df
# 19:56:57	Start processing HND_1413.
# 19:56:58	HND_1413 - Sums added to df
# 19:56:58	Start processing HND_1414.
# 19:57:00	HND_1414 - Sums added to df
# 19:57:00	Start processing HND_1415.
# 19:57:01	HND_1415 - Sums added to df
# 19:57:01	Start processing HND_1416.
# 19:57:04	HND_1416 - Sums added to df
# 19:57:04	Start processing HND_1417.
# 19:57:05	HND_1417 - Sums added to df
# 19:57:05	Start processing HND_1418.
# 19:57:06	HND_1418 - Sums added to df
# 19:57:06	Start processing HND_1419.
# 19:57:08	HND_1419 - Sums added to df
# 19:57:08	Start processing HND_1420.
# 19:57:09	HND_1420 - Sums added to df
# 19:57:09	Start processing HND_1421.
# 19:57:14	HND_1421 - Sums added to df
# 19:57:14	Start processing HND_1422.
# 19:57:16	HND_1422 - Sums added to df
# 19:57:16	Start processing HND_1423.
# 19:57:18	HND_1423 - Sums added to df
# 19:57:18	Start processing HND_1424.
# 19:57:19	HND_1424 - Sums added to df
# 19:57:19	Start processing HND_1425.
# 19:57:22	HND_1425 - Sums added to df
# 19:57:22	Start processing HND_2117.
# 19:57:26	HND_2117 - adm1 value error
# 19:57:26	Start processing HND_2118.
# 19:57:27	HND_2118 - Sums added to df
# 19:57:27	Start processing HND_2119.
# 19:57:27	HND_2119 - Sums added to df
# 19:57:27	HND - Completed
# 19:57:27	HRV: 1
# 19:57:28	HRV: Only one fluvial tile. No merge needed
# 19:57:30	HRV: Country level fluvial exported
# 19:57:30	HRV: Only one pluvial tile. No merge needed
# 19:57:32	HRV: Country level pluvial exported
# 19:57:32	Start processing HRV_996.
# 19:58:03	HRV_996 - Sums added to df
# 19:58:04	HRV - Completed
# 19:58:04	HTI: 10
# 19:58:04	HTI: Only one fluvial tile. No merge needed
# 19:58:04	HTI: Country level fluvial exported
# 19:58:04	HTI: Only one pluvial tile. No merge needed
# 19:58:05	HTI: Country level pluvial exported
# 19:58:05	Start processing HTI_1346.
# 19:58:06	HTI_1346 - Sums added to df
# 19:58:06	Start processing HTI_1347.
# 19:58:08	HTI_1347 - Sums added to df
# 19:58:08	Start processing HTI_1348.
# 19:58:09	HTI_1348 - Sums added to df
# 19:58:09	Start processing HTI_1349.
# ...
# 01:10:47	TZA: Country level pluvial exported
# 01:10:48	Start processing TZA_667.
# 01:10:58	TZA_667 - Sums added to df
# 01:10:59	Start processing TZA_668.
# 01:11:12	TZA_668 - Sums added to df
# 01:11:12	Start processing TZA_669.
# 01:11:21	TZA_669 - Sums added to df
# 01:11:21	Start processing TZA_670.
# 01:11:30	TZA_670 - Sums added to df
# 01:11:31	Start processing TZA_671.
# 01:11:43	TZA_671 - Sums added to df
# 01:11:43	Start processing TZA_672.
# 01:11:59	TZA_672 - Sums added to df
# 01:11:59	Start processing TZA_673.
# 01:12:07	TZA_673 - Sums added to df
# 01:12:07	Start processing TZA_674.
# 01:12:20	TZA_674 - Sums added to df
# 01:12:20	Start processing TZA_675.
# 01:12:25	TZA_675 - Sums added to df
# 01:12:25	Start processing TZA_676.
# 01:12:34	TZA_676 - Sums added to df
# 01:12:34	Start processing TZA_677.
# 01:12:40	TZA_677 - Sums added to df
# 01:12:40	Start processing TZA_678.
# 01:12:50	TZA_678 - Sums added to df
# 01:12:50	Start processing TZA_679.
# 01:12:56	TZA_679 - Sums added to df
# 01:12:56	Start processing TZA_680.
# 01:13:09	TZA_680 - Sums added to df
# 01:13:09	Start processing TZA_681.
# 01:13:14	TZA_681 - Sums added to df
# 01:13:14	Start processing TZA_682.
# 01:13:26	TZA_682 - Sums added to df
# 01:13:26	Start processing TZA_683.
# 01:13:32	TZA_683 - Sums added to df
# 01:13:32	Start processing TZA_684.
# 01:13:38	TZA_684 - Sums added to df
# 01:13:38	Start processing TZA_685.
# 01:13:46	TZA_685 - Sums added to df
# 01:13:46	Start processing TZA_686.
# 01:13:51	TZA_686 - Sums added to df
# 01:13:51	Start processing TZA_687.
# 01:13:58	TZA_687 - Sums added to df
# 01:13:58	Start processing TZA_688.
# 01:14:18	TZA_688 - Sums added to df
# 01:14:19	Start processing TZA_689.
# 01:14:29	TZA_689 - Sums added to df
# 01:14:29	Start processing TZA_690.
# 01:14:30	TZA_690 - Sums added to df
# 01:14:30	Start processing TZA_691.
# 01:14:44	TZA_691 - Sums added to df
# 01:14:45	Start processing TZA_692.
# 01:14:50	TZA_692 - Sums added to df
# 01:14:50	TZA - Completed
# 01:14:50	UGA: 4
# 01:14:50	UGA: Only one fluvial tile. No merge needed
# 01:14:52	UGA: Country level fluvial exported
# 01:14:53	UGA: Only one pluvial tile. No merge needed
# 01:14:55	UGA: Country level pluvial exported
# 01:14:55	Start processing UGA_1817.
# 01:15:06	UGA_1817 - Sums added to df
# 01:15:06	Start processing UGA_1818.
# 01:15:16	UGA_1818 - Sums added to df
# 01:15:16	Start processing UGA_1819.
# 01:15:34	UGA_1819 - Sums added to df
# 01:15:34	Start processing UGA_1820.
# 01:15:50	UGA_1820 - Sums added to df
# 01:15:50	UGA - Completed
# 01:15:50	UKR: 27
# 01:15:53	UKR: Only one fluvial tile. No merge needed
# 01:16:00	UKR: Country level fluvial exported
# 01:16:05	UKR: Only one pluvial tile. No merge needed
# 01:16:13	UKR: Country level pluvial exported
# 01:16:13	Start processing UKR_910.
# 01:16:23	UKR_910 - Sums added to df
# 01:16:23	Start processing UKR_911.
# 01:16:33	UKR_911 - Sums added to df
# 01:16:33	Start processing UKR_912.
# 01:16:37	UKR_912 - Sums added to df
# 01:16:37	Start processing UKR_913.
# 01:16:48	UKR_913 - Sums added to df
# 01:16:48	Start processing UKR_914.
# 01:16:58	UKR_914 - Sums added to df
# 01:16:59	Start processing UKR_915.
# 01:17:05	UKR_915 - Sums added to df
# 01:17:05	Start processing UKR_916.
# 01:17:16	UKR_916 - Sums added to df
# 01:17:16	Start processing UKR_917.
# 01:17:26	UKR_917 - Sums added to df
# 01:17:26	Start processing UKR_918.
# 01:17:34	UKR_918 - Sums added to df
# 01:17:34	Start processing UKR_919.
# 01:17:44	UKR_919 - Sums added to df
# 01:17:44	Start processing UKR_920.
# 01:17:55	UKR_920 - Sums added to df
# 01:17:55	Start processing UKR_921.
# 01:18:04	UKR_921 - Sums added to df
# 01:18:04	Start processing UKR_922.
# 01:18:14	UKR_922 - Sums added to df
# 01:18:14	Start processing UKR_923.
# 01:18:22	UKR_923 - Sums added to df
# 01:18:22	Start processing UKR_924.
# 01:18:36	UKR_924 - Sums added to df
# 01:18:36	Start processing UKR_925.
# 01:18:46	UKR_925 - Sums added to df
# 01:18:47	Start processing UKR_926.
# 01:18:55	UKR_926 - Sums added to df
# 01:18:55	Start processing UKR_927.
# 01:19:05	UKR_927 - Sums added to df
# 01:19:05	Start processing UKR_928.
# 01:19:11	UKR_928 - Sums added to df
# 01:19:11	Start processing UKR_929.
# 01:19:20	UKR_929 - Sums added to df
# 01:19:20	Start processing UKR_930.
# 01:19:27	UKR_930 - Sums added to df
# 01:19:27	Start processing UKR_931.
# 01:19:32	UKR_931 - Sums added to df
# 01:19:32	Start processing UKR_932.
# 01:19:41	UKR_932 - Sums added to df
# 01:19:41	Start processing UKR_933.
# 01:19:50	UKR_933 - Sums added to df
# 01:19:50	Start processing UKR_1022.
# 01:19:51	UKR_1022 - Sums added to df
# 01:19:51	Start processing UKR_1903.
# 01:20:02	UKR_1903 - Sums added to df
# 01:20:02	Start processing UKR_1904.
# 01:20:03	UKR_1904 - Sums added to df
# 01:20:03	UKR - Completed
# 01:20:03	URY: 19
# 01:20:03	URY: Only one fluvial tile. No merge needed
# 01:20:05	URY: Country level fluvial exported
# 01:20:06	URY: Only one pluvial tile. No merge needed
# 01:20:08	URY: Country level pluvial exported
# 01:20:08	Start processing URY_1381.
# 01:20:11	URY_1381 - Sums added to df
# 01:20:11	Start processing URY_1382.
# 01:20:13	URY_1382 - Sums added to df
# 01:20:13	Start processing URY_1383.
# 01:20:18	URY_1383 - Sums added to df
# 01:20:18	Start processing URY_1384.
# 01:20:20	URY_1384 - Sums added to df
# 01:20:20	Start processing URY_1385.
# 01:20:24	URY_1385 - Sums added to df
# 01:20:24	Start processing URY_1386.
# 01:20:26	URY_1386 - Sums added to df
# 01:20:26	Start processing URY_1387.
# 01:20:29	URY_1387 - Sums added to df
# 01:20:29	Start processing URY_1388.
# 01:20:32	URY_1388 - Sums added to df
# 01:20:33	Start processing URY_1389.
# 01:20:35	URY_1389 - Sums added to df
# 01:20:35	Start processing URY_1390.
# 01:20:35	URY_1390 - Sums added to df
# 01:20:35	Start processing URY_1391.
# 01:20:39	URY_1391 - Sums added to df
# 01:20:39	Start processing URY_1392.
# 01:20:42	URY_1392 - Sums added to df
# 01:20:42	Start processing URY_1393.
# 01:20:46	URY_1393 - Sums added to df
# 01:20:46	Start processing URY_1394.
# 01:20:49	URY_1394 - Sums added to df
# 01:20:49	Start processing URY_1395.
# 01:20:53	URY_1395 - Sums added to df
# 01:20:53	Start processing URY_1396.
# 01:20:55	URY_1396 - Sums added to df
# 01:20:55	Start processing URY_1397.
# 01:20:57	URY_1397 - Sums added to df
# 01:20:57	Start processing URY_1398.
# 01:21:02	URY_1398 - Sums added to df
# 01:21:02	Start processing URY_1399.
# 01:21:05	URY_1399 - Sums added to df
# 01:21:05	URY - Completed
# United States does not have flood data==================================
# 01:21:05	UZB: 14
# 01:21:08	UZB: Only one fluvial tile. No merge needed
# 01:21:16	UZB: Country level fluvial exported
# 01:21:20	UZB: Only one pluvial tile. No merge needed
# 01:21:28	UZB: Country level pluvial exported
# 01:21:28	Start processing UZB_368.
# 01:22:11	UZB_368 - Sums added to df
# 01:22:11	Start processing UZB_369.
# 01:22:13	UZB_369 - Sums added to df
# 01:22:13	Start processing UZB_370.
# 01:22:21	UZB_370 - Sums added to df
# 01:22:21	Start processing UZB_371.
# 01:22:24	UZB_371 - Sums added to df
# 01:22:24	Start processing UZB_372.
# 01:22:29	UZB_372 - Sums added to df
# 01:22:29	Start processing UZB_373.
# 01:22:30	UZB_373 - Sums added to df
# 01:22:30	Start processing UZB_374.
# 01:22:32	UZB_374 - Sums added to df
# 01:22:32	Start processing UZB_375.
# 01:22:45	UZB_375 - Sums added to df
# 01:22:45	Start processing UZB_376.
# 01:22:52	UZB_376 - Sums added to df
# 01:22:52	Start processing UZB_377.
# 01:22:59	UZB_377 - Sums added to df
# 01:22:59	Start processing UZB_378.
# 01:23:32	UZB_378 - Sums added to df
# 01:23:32	Start processing UZB_379.
# 01:23:35	UZB_379 - Sums added to df
# 01:23:35	Start processing UZB_380.
# 01:23:41	UZB_380 - Sums added to df
# 01:23:41	Start processing UZB_381.
# 01:23:46	UZB_381 - Sums added to df
# 01:23:46	UZB - Completed
# 01:23:46	VCT: 6
# 01:23:46	VCT: No fluvial files found.
# 01:23:46	VCT: Only one pluvial tile. No merge needed
# 01:23:47	VCT: Country level pluvial exported
# 01:23:47	Start processing VCT_2096.
# 01:23:47	VCT_2096 - adm1 other error
# 01:23:47	Start processing VCT_2097.
# 01:23:47	VCT_2097 - adm1 other error
# 01:23:47	Start processing VCT_2098.
# 01:23:47	VCT_2098 - adm1 other error
# 01:23:47	Start processing VCT_2099.
# 01:23:47	VCT_2099 - adm1 other error
# 01:23:47	Start processing VCT_2100.
# 01:23:47	VCT_2100 - adm1 other error
# 01:23:47	Start processing VCT_2112.
# 01:23:47	VCT_2112 - adm1 other error
# 01:23:47	VCT - Completed
# 01:23:47	VEN: 9
# 01:23:50	VEN: Only one fluvial tile. No merge needed
# 01:24:00	VEN: Country level fluvial exported
# 01:24:05	VEN: Only one pluvial tile. No merge needed
# 01:24:16	VEN: Country level pluvial exported
# 01:24:17	Start processing VEN_225.
# 01:24:19	VEN_225 - Sums added to df
# 01:24:19	Start processing VEN_226.
# 01:24:28	VEN_226 - Sums added to df
# 01:24:28	Start processing VEN_227.
# 01:24:35	VEN_227 - Sums added to df
# 01:24:35	Start processing VEN_228.
# 01:24:54	VEN_228 - Sums added to df
# 01:24:54	Start processing VEN_229.
# 01:26:42	VEN_229 - Sums added to df
# 01:26:43	Start processing VEN_230.
# 01:27:02	VEN_230 - Sums added to df
# 01:27:02	Start processing VEN_231.
# 01:27:16	VEN_231 - Sums added to df
# 01:27:16	Start processing VEN_232.
# 01:27:39	VEN_232 - Sums added to df
# 01:27:39	Start processing VEN_233.
# 01:28:13	VEN_233 - Sums added to df
# 01:28:14	VEN - Completed
# 01:28:14	VNM: 6
# 01:28:16	VNM: Only one fluvial tile. No merge needed
# 01:28:21	VNM: Country level fluvial exported
# 01:28:25	VNM: Only one pluvial tile. No merge needed
# 01:28:31	VNM: Country level pluvial exported
# 01:28:31	Start processing VNM_752.
# 01:29:32	VNM_752 - Sums added to df
# 01:29:32	Start processing VNM_1893.
# 01:29:44	VNM_1893 - Sums added to df
# 01:29:44	Start processing VNM_1894.
# 01:29:57	VNM_1894 - Sums added to df
# 01:29:57	Start processing VNM_1895.
# 01:30:21	VNM_1895 - Sums added to df
# 01:30:21	Start processing VNM_1896.
# 01:30:27	VNM_1896 - Sums added to df
# 01:30:27	Start processing VNM_1897.
# 01:30:43	VNM_1897 - Sums added to df
# 01:30:44	VNM - Completed
# 01:30:44	VUT: 6
# 01:30:44	VUT: Only one fluvial tile. No merge needed
# 01:30:45	VUT: Country level fluvial exported
# 01:30:46	VUT: Only one pluvial tile. No merge needed
# 01:30:48	VUT: Country level pluvial exported
# 01:30:48	Start processing VUT_1163.
# 01:30:49	VUT_1163 - Sums added to df
# 01:30:49	Start processing VUT_1164.
# 01:30:50	VUT_1164 - Sums added to df
# 01:30:50	Start processing VUT_1165.
# 01:30:52	VUT_1165 - Sums added to df
# 01:30:52	Start processing VUT_1166.
# 01:30:53	VUT_1166 - Sums added to df
# 01:30:53	Start processing VUT_1167.
# 01:30:56	VUT_1167 - Sums added to df
# 01:30:56	Start processing VUT_1168.
# 01:30:59	VUT_1168 - Sums added to df
# 01:30:59	VUT - Completed
# 01:30:59	WSM: 2
# 01:30:59	WSM: No fluvial files found.
# 01:30:59	WSM: Only one pluvial tile. No merge needed
# 01:30:59	WSM: Country level pluvial exported
# 01:30:59	Start processing WSM_24.
# 01:30:59	WSM_24 - adm1 other error
# 01:30:59	Start processing WSM_25.
# 01:30:59	WSM_25 - adm1 other error
# 01:30:59	WSM - Completed
# 01:30:59	XKX: 7
# 01:30:59	XKX: Only one fluvial tile. No merge needed
# 01:30:59	XKX: Country level fluvial exported
# 01:30:59	XKX: Only one pluvial tile. No merge needed
# 01:31:00	XKX: Country level pluvial exported
# 01:31:00	Start processing XKX_382.
# 01:31:00	XKX_382 - no pop file
# 01:31:00	Start processing XKX_383.
# 01:31:00	XKX_383 - no pop file
# 01:31:00	Start processing XKX_384.
# 01:31:00	XKX_384 - no pop file
# 01:31:00	Start processing XKX_385.
# 01:31:00	XKX_385 - no pop file
# 01:31:00	Start processing XKX_386.
# 01:31:00	XKX_386 - no pop file
# 01:31:00	Start processing XKX_387.
# 01:31:01	XKX_387 - no pop file
# 01:31:01	Start processing XKX_388.
# 01:31:01	XKX_388 - no pop file
# 01:31:01	XKX - Completed
# 01:31:01	YEM: 22
# 01:31:02	YEM: Only one fluvial tile. No merge needed
# 01:31:07	YEM: Country level fluvial exported
# 01:31:09	YEM: Only one pluvial tile. No merge needed
# 01:31:14	YEM: Country level pluvial exported
# 01:31:14	Start processing YEM_524.
# 01:31:16	YEM_524 - Sums added to df
# 01:31:16	Start processing YEM_525.
# 01:31:20	YEM_525 - Sums added to df
# 01:31:20	Start processing YEM_526.
# 01:31:21	YEM_526 - Sums added to df
# 01:31:21	Start processing YEM_527.
# 01:31:23	YEM_527 - Sums added to df
# 01:31:23	Start processing YEM_528.
# 01:31:26	YEM_528 - Sums added to df
# 01:31:26	Start processing YEM_529.
# 01:31:33	YEM_529 - Sums added to df
# 01:31:33	Start processing YEM_530.
# 01:31:37	YEM_530 - Sums added to df
# 01:31:37	Start processing YEM_531.
# 01:31:43	YEM_531 - Sums added to df
# 01:31:43	Start processing YEM_532.
# 01:32:21	YEM_532 - Sums added to df
# 01:32:22	Start processing YEM_533.
# 01:32:24	YEM_533 - Sums added to df
# 01:32:24	Start processing YEM_534.
# 01:32:33	YEM_534 - Sums added to df
# 01:32:33	Start processing YEM_535.
# 01:32:37	YEM_535 - Sums added to df
# 01:32:37	Start processing YEM_536.
# 01:32:40	YEM_536 - Sums added to df
# 01:32:40	Start processing YEM_537.
# 01:32:41	YEM_537 - Sums added to df
# 01:32:41	Start processing YEM_538.
# 01:32:45	YEM_538 - Sums added to df
# 01:32:45	Start processing YEM_539.
# 01:32:51	YEM_539 - Sums added to df
# 01:32:51	Start processing YEM_540.
# 01:32:52	YEM_540 - Sums added to df
# 01:32:52	Start processing YEM_541.
# 01:33:09	YEM_541 - Sums added to df
# 01:33:09	Start processing YEM_542.
# 01:33:12	YEM_542 - Sums added to df
# 01:33:12	Start processing YEM_543.
# 01:33:13	YEM_543 - Sums added to df
# 01:33:13	Start processing YEM_544.
# 01:33:14	YEM_544 - Sums added to df
# 01:33:14	Start processing YEM_545.
# 01:33:21	YEM_545 - Sums added to df
# 01:33:21	YEM - Completed
# 01:33:21	ZAF: 9
# 01:33:28	ZAF: Only one fluvial tile. No merge needed
# 01:33:50	ZAF: Country level fluvial exported
# 01:34:03	ZAF: Only one pluvial tile. No merge needed
# 01:34:26	ZAF: Country level pluvial exported
# 01:34:26	Start processing ZAF_1623.
# 01:35:15	ZAF_1623 - Sums added to df
# 01:35:15	Start processing ZAF_1624.
# 01:35:50	ZAF_1624 - Sums added to df
# 01:35:50	Start processing ZAF_1625.
# 01:35:56	ZAF_1625 - Sums added to df
# 01:35:57	Start processing ZAF_1626.
# 01:36:27	ZAF_1626 - Sums added to df
# 01:36:27	Start processing ZAF_1627.
# 01:36:48	ZAF_1627 - Sums added to df
# 01:36:48	Start processing ZAF_1628.
# 01:37:17	ZAF_1628 - Sums added to df
# 01:37:18	Start processing ZAF_1629.
# 01:39:26	ZAF_1629 - Sums added to df
# 01:39:27	Start processing ZAF_1630.
# 01:39:53	ZAF_1630 - Sums added to df
# 01:39:53	Start processing ZAF_1631.
# 01:47:30	ZAF_1631 - Sums added to df
# 01:47:32	ZAF - Completed
# 01:47:32	ZMB: 10
# 01:47:34	ZMB: Only one fluvial tile. No merge needed
# 01:47:40	ZMB: Country level fluvial exported
# 01:47:45	ZMB: Only one pluvial tile. No merge needed
# 01:47:53	ZMB: Country level pluvial exported
# 01:47:54	Start processing ZMB_822.
# 01:48:12	ZMB_822 - Sums added to df
# 01:48:12	Start processing ZMB_823.
# 01:48:37	ZMB_823 - Sums added to df
# 01:48:37	Start processing ZMB_824.
# 01:48:54	ZMB_824 - Sums added to df
# 01:48:54	Start processing ZMB_825.
# 01:49:25	ZMB_825 - Sums added to df
# 01:49:25	Start processing ZMB_826.
# 01:49:32	ZMB_826 - Sums added to df
# 01:49:32	Start processing ZMB_827.
# 01:49:45	ZMB_827 - Sums added to df
# 01:49:45	Start processing ZMB_828.
# 01:49:50	ZMB_828 - Sums added to df
# 01:49:51	Start processing ZMB_829.
# 01:50:21	ZMB_829 - Sums added to df
# 01:50:21	Start processing ZMB_830.
# 01:50:39	ZMB_830 - Sums added to df
# 01:50:39	Start processing ZMB_831.
# 01:51:02	ZMB_831 - Sums added to df
# 01:51:03	ZMB - Completed
# 01:51:03	ZWE: 10
# 01:51:04	ZWE: Only one fluvial tile. No merge needed
# 01:51:06	ZWE: Country level fluvial exported
# 01:51:08	ZWE: Only one pluvial tile. No merge needed
# 01:51:12	ZWE: Country level pluvial exported
# 01:51:13	Start processing ZWE_614.
# 01:51:13	ZWE_614 - Sums added to df
# 01:51:13	Start processing ZWE_615.
# 01:51:14	ZWE_615 - Sums added to df
# 01:51:14	Start processing ZWE_616.
# 01:51:27	ZWE_616 - Sums added to df
# 01:51:27	Start processing ZWE_617.
# 01:51:35	ZWE_617 - Sums added to df
# 01:51:35	Start processing ZWE_618.
# 01:51:45	ZWE_618 - Sums added to df
# 01:51:45	Start processing ZWE_619.
# 01:52:00	ZWE_619 - Sums added to df
# 01:52:01	Start processing ZWE_620.
# 01:52:15	ZWE_620 - Sums added to df
# 01:52:15	Start processing ZWE_621.
# 01:52:35	ZWE_621 - Sums added to df
# 01:52:35	Start processing ZWE_622.
# 01:52:53	ZWE_622 - Sums added to df
# 01:52:53	Start processing ZWE_623.
# 01:53:11	ZWE_623 - Sums added to df
# 01:53:11	ZWE - Completed

# %% [markdown]
# # Functions

# %%
def get_FP_2019(flood_name, path_name, pfFlood_Folder):
  floodList = []
  for name in path_name.glob(flood_name):
      floodFolder = path_name / name / pfFlood_Folder
      if len(list(floodFolder.rglob('*100.tif'))) == 0:
          # Large countries have multiple FU_1in100-x.tif files (x = tile number)
          floodList = list(floodFolder.rglob('*100_tile_?.tif'))
      else:
          # Small countries have one FU_1in100.tif file
          floodList = list(floodFolder.rglob('*100.tif'))
  return floodList

def open_files_in_list(fileList):
    outputList = []
    for fp in fileList:
        src = rs.open(fp)
        outputList.append(src) 
    return outputList

def merge_export_adm0_FP_files(flood_files_list, outpath, countryCode, FP):
    if len(flood_files_list) >=1:
      # if multiple flood files exist, merge then export
      if len(flood_files_list) >1: 
          # Merge flood files.
          floodArray, out_trans = merge(flood_files_list, method='max')
          tPrint(f'{countryCode}: Country level {FP} merged') 
          ## Update the metadata
          out_meta = flood_files_list[0].meta.copy()
          out_meta.update({"height": floodArray.shape[1], 
                            "width": floodArray.shape[2],
                            "transform": out_trans})
      elif len(flood_files_list) ==1: 
          floodArray = flood_files_list[0].read()
          out_meta = flood_files_list[0].meta.copy()
          tPrint(f'{countryCode}: Only one {FP} tile. No merge needed')
      # export as a new geotiff 
      floodName = f"{FP}_{countryCode}.tif"
      merged_outputfile = outpath / floodName
      with rs.open(merged_outputfile, 'w', **out_meta, compress = 'LZW', tiled=True) as dest:
          dest.write(floodArray)
      tPrint(f'{countryCode}: Country level {FP} exported') 
    else:
      tPrint(f'{countryCode}: No {FP} files found.')
      merged_outputfile = outpath # fix or use this in next loop
    return merged_outputfile

# %%
def adm0_processing_2019(flood_name):
    # all other variables used are global
    ###################### Fluvial Adm0 ######################
    if flood_name == ['Fiji_east', 'Fiji_west']: 
      fluvialList = FJfluvial 
    else: 
      fluvialList = get_FP_2019(flood_name, flood_path_2019, fluvialFlood_Folder) 

    fluvialFiles = open_files_in_list(fluvialList)      
    Fluvial_outputfile = merge_export_adm0_FP_files(fluvialFiles, FP_outputFolderPath, countryCode, 'fluvial')

    ###################### Pluvial Adm0 ######################
    # Create list of pluvial flood files
    if flood_name == ['Fiji_east', 'Fiji_west']:
      pluvialList = FJ_E_pluvial + FJ_W_pluvial
    else:
      pluvialList = get_FP_2019(flood_name, flood_path_2019, pluvialFlood_Folder)

    pluvialFiles = open_files_in_list(pluvialList)  
    Pluvial_outputfile = merge_export_adm0_FP_files(pluvialFiles, FP_outputFolderPath, countryCode, 'pluvial')

    return Fluvial_outputfile, Pluvial_outputfile

# %%
def get_adm1_index(df_adm1):
    adm1Index = str(df_adm1.index)
    adm1Index = adm1Index.partition("[")[2].partition("]")[0]
    return adm1Index

def crop_to_shp(path_name, df, filePrefix):
    raster = rs.open(path_name)
    # Mask to shapefile
    out_array, out_trans = rs.mask.mask(dataset=raster, shapes=df.geometry, crop=True)

    out_meta = raster.meta.copy()
    out_meta.update({"height": out_array.shape[1], 
                      "width": out_array.shape[2],
                      "transform": out_trans})
    #tPrint(f"{countryCode}_{adm1Index} - {filePrefix} cropped to adm 1")
    return out_array, out_meta
    
def export_raster_to_geotiff(array, meta, path, fileName, filePrefix):
    Cropped_outputfile = path / fileName
    with rs.open(Cropped_outputfile, 'w', **meta, compress = 'LZW', tiled=True) as dest:
        dest.write(array)
    return Cropped_outputfile
    #tPrint(f"{countryCode}_{adm1Index} - {filePrefix} exported")
    
def vrtWarp(inpath, outpath, vrt_settings, country_code, adm_code, filePrefix):
    with rs.open(inpath) as src:
      with WarpedVRT(src, **vrt_settings) as vrt:
          data = vrt.read()
          # Process the dataset in chunks. 
          for _, window in vrt.block_windows(): data = vrt.read(window=window)
          # Export the aligned data 
          fileName = f"{filePrefix}_{country_code}_{adm_code}.tif"
          Aligned_outputfile = outpath / fileName        
          rio_shutil.copy(vrt, Aligned_outputfile, driver='GTiff')
    #tPrint(f"{countryCode}_{adm1Index} - {filePrefix} aligned")
    return Aligned_outputfile

def convert_to_bool_int_array(array):
      listNumberCat = range(numberCategories)
      list_IntBool_floodCat = []
      # Create a boolean int array for each category
      for i in listNumberCat:
          intArray = (array == i).astype(dtype = np.int8, copy = False)
          list_IntBool_floodCat.append(intArray)
      #tPrint(f"{countryCode}_{adm1Index} - Flood converted to bool int arrays")
      return list_IntBool_floodCat

def multiply_array_list(arrayList, array):
      flood_pop = []
      for i in range(len(arrayList)):
          flood_pop.append(np.multiply(arrayList[i], array))
      flood_pop = (np.vstack((flood_pop)))
      #tPrint(f"{countryCode}_{adm1Index} - Flood multiplied by pop")
      return flood_pop

# def multiply_array_list(arrayList, array):
# #     flood_pop = []
#     for i in range(len(arrayList)):
#         arrayList[i] = np.multiply(arrayList[i], array)
# #         flood_pop.append(np.multiply(arrayList[i], array))
# #         arrayList = arrayList[1:]
# #     flood_pop = (np.vstack((flood_pop)))
#     flood_pop = (np.vstack((arrayList)))
#     tPrint(f"{countryCode}_{adm1Index} - Flood multiplied by pop")
#     return flood_pop

def array3d_sum(array):
      Flood_pop_sums = {
        '0-NoRiskPop': np.sum(array[0]),
        '1-LowRiskPop': np.sum(array[1]),
        '2-ModerateRiskPop': np.sum(array[2]),
        '3-HighRiskPop': np.sum(array[3]),
        '4-VeryHighRiskPop': np.sum(array[4]),
        '5-WaterBodyPop': np.sum(array[5])
      }
      #tPrint(f"{countryCode}_{adm1Index} - Checksum: {np.sum(array)}")
      return Flood_pop_sums

def sums_to_df(sums, df):
      for key,value in sums.items() :
        df.loc[int(adm1Index), key] = value

      # rounding the values to x decimal places
      df.iloc[:,-6:] = df.iloc[:,-6:].apply(lambda x: round(x, 2));

      # Keeping only results cols to make merge easy
      df = df.iloc[:,-6:] 
      df['ISO3'] = countryCode
      return df

# %%
def adm1_processing(adm1, resultDF):
    ###################### Fluvial Adm1 ######################
    # crop
    floodArray, out_meta = crop_to_shp(Fluvial_outputfile, adm1, 'Fluvial')
    # export
    fluvialCroppedName = f"FU_{countryCode}_{adm1Index}.tif"
    FluvialCropped_outputfile = export_raster_to_geotiff(floodArray, out_meta, FP_outputFolderPath, 
                                                        fluvialCroppedName, 'Fluvial')
    
    # ###################### Pluvial Adm1 ######################
    # crop
    floodArray, out_meta = crop_to_shp(Pluvial_outputfile, adm1, 'Pluvial')
    # export
    pluvialCroppedName = f"PU_{countryCode}_{adm1Index}.tif"
    PluvialCropped_outputfile = export_raster_to_geotiff(floodArray, out_meta, FP_outputFolderPath, 
                                                        pluvialCroppedName, 'Pluvial')
    
    ###################### WarpedVRT ######################
    # Vritually warp the pop and coastal flood files to the fluvial and pluvial
    vrt_options ={
        'resampling': Resampling.nearest,
        'crs': out_meta['crs'],
        'transform' : out_meta['transform'],
        'height':floodArray.shape[1],
        'width': floodArray.shape[2]
    }

    ###################### Population ######################
    # Get population file
    pop_File = " "
    countryAlpha3 = f'*{countryCode}*'
    for name in population_path.glob(countryAlpha3):
        pop_File = name
    if pop_File != " ":
        # Align using Warped VRT
        popAligned_outputfile = vrtWarp(pop_File, PopAligned_outputFolderPath, vrt_options, countryCode, adm1Index, 'popAligned')
        pop = rs.open(popAligned_outputfile)
        # crop
        popArray, out_meta = crop_to_shp(popAligned_outputfile, adm1, 'Pop')
        # change dtype to reduce memory
        popArray = popArray.astype('float32', copy=False)
        out_meta.update({'dtype': 'float32'})
        # export
        popCropped = f"PopCropped_{countryCode}_{adm1Index}.tif"
        export_raster_to_geotiff(popArray, out_meta, PopAligned_outputFolderPath, popCropped, 'popCropped')
        # Remove negatives
        popArray[popArray < 0] = 0
        # Print population sum for country to compare against final results
        #tPrint(f"{countryCode}_{adm1Index} - Pop aligned & cropped. Total Pop: {np.sum(popArray)}")

        ###################### Coastal Adm1 ######################
        # Align using Warped VRT
        cFloodAligned_outputfile = vrtWarp(coastalFlood_path, cFlood_outputFolderPath,  
                                        vrt_options, countryCode, adm1Index, 'AlignedCoastalFlood')
        # At this point the coastal flood file is aligned and has been cropped to the pop bounding box
        # It will be cropped to the adm1 boundaries after merging with the fluvail and pluvial files
        #tPrint(f"{countryCode}_{adm1Index} - Coastal aligned")

        ###################### Flood mosaic adm1 ######################
        # Create flood mosaic
        combinedFloodList = [FluvialCropped_outputfile] + [PluvialCropped_outputfile] + [cFloodAligned_outputfile]            
        allFiles = []
        for fp in combinedFloodList:
            src = rs.open(fp)
            allFiles.append(src)

        # Merge flood files. Using max pixel by pixel method
        floodArray, out_trans = merge(allFiles, method='max')
        out_meta = allFiles[0].meta.copy()
        out_meta.update({"height": floodArray.shape[1], 
                          "width": floodArray.shape[2],
                          "transform": out_trans})
        
        # export
        floodNameMerged = f"FloodMerged_{countryCode}_{adm1Index}.tif"
        FloodMerged_outputfile = export_raster_to_geotiff(floodArray, out_meta, Flood_outputFolderPath, floodNameMerged, 'FloodMerged')
        #tPrint(f'{countryCode}_{adm1Index} - Flood mosaic merged & exported') 

        # ###################### Crop merged file flood ######################
        # crop
        floodArray, out_meta = crop_to_shp(FloodMerged_outputfile, adm1, 'FloodCropped')
        # export
        floodName = f"Flood_{countryCode}_{adm1Index}.tif"
        FloodCropped_outputfile = export_raster_to_geotiff(floodArray, out_meta, Flood_outputFolderPath, 
                                                            floodName, 'FloodCropped')
        #tPrint(f'{countryCode}_{adm1Index} - Confirming same shape. popArray shape: {popArray.shape} floodArray shape: {floodArray.shape}')

        ###################### Categorize by flood bins ######################
        floodArray = np.digitize(floodArray, flood_bins, right=True) # True to include right bin edge
        floodArray = floodArray.astype(dtype = np.int8, copy = False)
        #tPrint(f"{countryCode}_{adm1Index} - Flood categorized") 

        ###################### Convert to bool int arrays ######################
        list_IntBool_floodCat = convert_to_bool_int_array(floodArray)
        del floodArray

        ###################### Multiply flood array by pop array ######################
        # Multiply each int bool categorized flood array by the population array
        flood_pop = multiply_array_list(list_IntBool_floodCat, popArray)
        del list_IntBool_floodCat

        ##################### Export flood pop raster ######################
        # update meta
        out_meta.update({"nodata": 0., 'count': numberCategories})
        # export
        FloodPopName = f"FloodPop_{countryCode}_{adm1Index}.tif"
        export_raster_to_geotiff(flood_pop, out_meta, Raster_outputFolderPath, FloodPopName, 'flood pop stack')

        # ###################### Calculate sum for each exposure array ######################
        Flood_pop_sums = array3d_sum(flood_pop)

        #################################### Add to df ####################################
        adm1 = sums_to_df(Flood_pop_sums, adm1)
        resultDF = resultDF.append(adm1)
        tPrint(f"{countryCode}_{adm1Index} - Sums added to df")
    else:
        tPrint(f"{countryCode}_{adm1Index} - no pop file")
    return resultDF

# %%
def adm1_loop(sub_df, result_df):
  for namedTuple in sub_df.itertuples():
    adm1 = sub_df.loc[[int(namedTuple[0])]]
    adm1 = adm1[['ADM0_NAME','geometry']] 
    global adm1Index # making adm1Index global 
    adm1Index = get_adm1_index(adm1)
    adm1_name = f'{countryCode}_{adm1Index}' #countryCode is global
    # skip bad_adm1
    global bad_adm1 
    if adm1_name in bad_adm1: #bad_adm1 is global
        tPrint(f'{adm1_name} is bad')
    else:
        tPrint(f'Start processing {adm1_name}.')
        try: # main processing happens hhere
            result_df = adm1_processing(adm1, result_df) #result is global
        except rasterio.errors.WindowError:
            #bad_adm1.append(f'{countryCode}_{adm1Index}')
            tPrint(f"{countryCode}_{adm1Index} - adm1 window error")
            continue
        except ValueError:
            #bad_adm1.append(f'{countryCode}_{adm1Index}')
            tPrint(f"{countryCode}_{adm1Index} - adm1 value error")
            continue
        except MemoryError:
            #bad_adm1.append(f'{countryCode}_{adm1Index}')
            tPrint(f"{countryCode}_{adm1Index} - adm1 memory error")
            continue
        except:
            #bad_adm1.append(f'{countryCode}_{adm1Index}')
            tPrint(f"{countryCode}_{adm1Index} - adm1 other error")
            continue
  return result_df

# %% [markdown]
# ## Merge & Exporting

# %%
# removing ISO3 col because it's in the results df
adm = adm[['ADM0_NAME', 'code', 'sample', 'region', 'geo_code2','geometry']]

# %%
# creating a merged df with only rows that have new results:
mergedDf1 = adm.merge(result, left_index=True, right_index=True)

# %%
# checking all looks good
mergedDf1.head()
# Out:
#                 ADM0_NAME code              sample region  \
# 0   Micronesia, Fed. Sts.  FSM               1–Yap    EAP
# 1   Micronesia, Fed. Sts.  FSM             2–Chuuk    EAP
# 3   Micronesia, Fed. Sts.  FSM            4–Kosrae    EAP
# 26              Australia  AUS  [1]New South Wales    EAP
# 27              Australia  AUS         [2]Victoria    EAP
#
#                      geo_code2  \
# 0   FSM_2013_GADM1_FSM_FSM.4_1
# 1   FSM_2013_GADM1_FSM_FSM.1_1
# 3   FSM_2013_GADM1_FSM_FSM.2_1
# 26           AUS_2014_ADM1_470
# 27           AUS_2014_ADM1_476
#
#                                              geometry  0-NoRiskPop  \
# 0   (POLYGON ((143.07833862 6.684165949999993, 143...     10205.07
# 1   (POLYGON ((153.6361084 5.291110039999997, 153....     40862.93
# 3   (POLYGON ((162.96694946 5.281112189999991, 162...      3892.86
# 26  (POLYGON ((151.172748 -33.847877, 151.173537 -...   5999717.00
# 27  (POLYGON ((146.33117676 -39.14710998000001, 14...   4546959.00
#
#     1-LowRiskPop  2-ModerateRiskPop  3-HighRiskPop  4-VeryHighRiskPop  \
# 0         467.60             190.62          62.79              65.78
# 1        1047.28             728.74         196.33              76.56
# 3         586.87             422.93         267.92              52.50
# 26     370404.81          227553.67      128814.43           50928.25
# 27     398618.84          219808.27      119916.20           36683.57
#
#     5-WaterBodyPop ISO3
# 0             0.97  FSM
# 1            33.35  FSM
# 3             0.00  FSM
# 26         3555.13  AUS
# 27          282.05  AUS

# %%
# Exporting 
mergedDf1.to_file(Results_outputFolderPath / "processed_countries_1.shp")
# Out:
# WARNING:fiona._env:Normalized/laundered field name: '0-NoRiskPop' to '0-NoRiskPo'
# WARNING:fiona._env:Normalized/laundered field name: '1-LowRiskPop' to '1-LowRiskP'
# WARNING:fiona._env:Normalized/laundered field name: '2-ModerateRiskPop' to '2-Moderate'
# WARNING:fiona._env:Normalized/laundered field name: '3-HighRiskPop' to '3-HighRisk'
# WARNING:fiona._env:Normalized/laundered field name: '4-VeryHighRiskPop' to '4-VeryHigh'
# WARNING:fiona._env:Normalized/laundered field name: '5-WaterBodyPop' to '5-WaterBod'
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# ...
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
# WARNING:fiona._env:One or several characters couldn't be converted correctly from UTF-8 to ISO-8859-1.  This warning will not be emitted anymore.
